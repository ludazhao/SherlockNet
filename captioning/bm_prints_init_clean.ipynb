# %%
import os.path
import re
import sys
import numpy as np
import json
import time
from six.moves import urllib
import matplotlib as mpl
from pprint import pprint
import pandas as pd

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
#Load the data
data = None
l
with open('/data/captioning/bm_prints_urls_captions.json') as f:
    data = json.load(f)

# %%
img_arr = data['results']['bindings']
len(img_arr)
# Out:
# 782550

# %%
pprint(img_arr[0:20])
# Out:
# [{u'caption': {u'type': u'literal',
#                u'value': u'From the animal legend; antelope to left, another(?) lying centre. 1912\nWoodcut'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/PPA8330'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00107/AN00107870_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'From the animal legend; antelope to left, another(?) lying centre. 1912\nWoodcut'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/P_1982-0724-21'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00107/AN00107870_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'From the animal legend; antelope to left, another(?) lying centre. 1912\nWoodcut'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/1045'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00107/AN00107870_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Woodblock print. Giant lantern in the Kaminari-mon of Senso-ji temple.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/JCF11708'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00489/AN00489936_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Woodblock print. Giant lantern in the Kaminari-mon of Senso-ji temple.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/J_1981-0225-0-4-a'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00489/AN00489936_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Woodblock print. Giant lantern in the Kaminari-mon of Senso-ji temple.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/1405'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00489/AN00489936_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Woodblock print. Spring night at Ginza.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/JCF11709'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00244/AN00244222_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Woodblock print. Spring night at Ginza.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/J_1981-0225-0-4-b'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00244/AN00244222_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Woodblock print. Spring night at Ginza.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/1406'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00244/AN00244222_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Le Mont de Neuville; street winding to right beyond, flanked by buildings on both sides, at right figure in doorway and beyond figure standing in middle of road. 1899\nCharcoal (?), with watercolour, over monotype'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/PDB17329'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00266/AN00266509_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Le Mont de Neuville; street winding to right beyond, flanked by buildings on both sides, at right figure in doorway and beyond figure standing in middle of road. 1899\nCharcoal (?), with watercolour, over monotype'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/P_1981-0328-5'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00266/AN00266509_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Le Mont de Neuville; street winding to right beyond, flanked by buildings on both sides, at right figure in doorway and beyond figure standing in middle of road. 1899\nCharcoal (?), with watercolour, over monotype'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/1551'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00266/AN00266509_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Monochrome woodblock print. Subodai standing. Signed, sealed, inscribed and marked.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/JCF11731'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00225/AN00225242_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Monochrome woodblock print. Subodai standing. Signed, sealed, inscribed and marked.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/J_1981-0331-0-2'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00225/AN00225242_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Monochrome woodblock print. Subodai standing. Signed, sealed, inscribed and marked.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/1563'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00225/AN00225242_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Colour woodblock print with powdered mica background. Woman in loose kimono sitting on cushion in front of mirror. Signed, dated and sealed.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/JCF11738'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00224/AN00224520_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Colour woodblock print with powdered mica background. Woman in loose kimono sitting on cushion in front of mirror. Signed, dated and sealed.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/J_1981-0410-0-2'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00224/AN00224520_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Colour woodblock print with powdered mica background. Woman in loose kimono sitting on cushion in front of mirror. Signed, dated and sealed.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/1621'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00224/AN00224520_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Woodblock print. Beauty with unrolled obi?'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/JCF11739'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00244/AN00244199_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Woodblock print. Beauty with unrolled obi?'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/J_1981-0410-0-3'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00244/AN00244199_001_l.jpg'}}]

# %%
start = time.time()

# Filter by unqiue uris
from pandas.io.json import json_normalize

df = json_normalize(img_arr)
df.drop('caption.type', axis=1, inplace=True)
df.drop('print.type', axis=1, inplace=True)
df.drop('url.type', axis=1, inplace=True)
df.head()

print "Time:" + str(time.time() - start)
# Out:
# Time:52.4418330193

# %%
df.head()
# Out:
#                                        caption.value  \
# 0  From the animal legend; antelope to left, anot...
# 1  From the animal legend; antelope to left, anot...
# 2  From the animal legend; antelope to left, anot...
# 3  Woodblock print. Giant lantern in the Kaminari...
# 4  Woodblock print. Giant lantern in the Kaminari...
#
#                                          print.value  \
# 0  http://collection.britishmuseum.org/id/object/...
# 1  http://collection.britishmuseum.org/id/object/...
# 2  http://collection.britishmuseum.org/id/object/...
# 3  http://collection.britishmuseum.org/id/object/...
# 4  http://collection.britishmuseum.org/id/object/...
#
#                                            url.value
# 0  http://www.britishmuseum.org/collectionimages/...
# 1  http://www.britishmuseum.org/collectionimages/...
# 2  http://www.britishmuseum.org/collectionimages/...
# 3  http://www.britishmuseum.org/collectionimages/...
# 4  http://www.britishmuseum.org/collectionimages/...

# %%
# Drop duplicates according to caption.value and url.value
start = time.time()

print len(df)
df.drop_duplicates(subset=['caption.value', 'url.value'], inplace=True)
print len(df)

print "Time:" + str(time.time() - start)
# Out:
# 782550
# 258103
# Time:8.21036314964

# %%
df_count = df.groupby(['url.value']).size().reset_index().rename(columns={0:'count'})

# %%
# look if some objects have more than 1 captions
df_count['count'].value_counts()
# Out:
# 1    253884
# 2      2072
# 3        11
# 4         6
# 6         3
# Name: count, dtype: int64

# %%
#Drop further dup urls
df.drop_duplicates(subset=['url.value'], inplace=True)
print len(df)
# Out:
# 255976

# %%
# get shortering data to work with
df_tiny = df[:5].copy()

# %%
df_tiny['capt_length'] = df_tiny['caption.value'].map(lambda x: len(x.split()))
df_tiny
# Out:
#                                         caption.value  \
# 0   From the animal legend; antelope to left, anot...
# 3   Woodblock print. Giant lantern in the Kaminari...
# 6             Woodblock print. Spring night at Ginza.
# 9   Le Mont de Neuville; street winding to right b...
# 12  Monochrome woodblock print. Subodai standing. ...
#
#                                           print.value  \
# 0   http://collection.britishmuseum.org/id/object/...
# 3   http://collection.britishmuseum.org/id/object/...
# 6   http://collection.britishmuseum.org/id/object/...
# 9   http://collection.britishmuseum.org/id/object/...
# 12  http://collection.britishmuseum.org/id/object/...
#
#                                             url.value  capt_length
# 0   http://www.britishmuseum.org/collectionimages/...           12
# 3   http://www.britishmuseum.org/collectionimages/...           10
# 6   http://www.britishmuseum.org/collectionimages/...            6
# 9   http://www.britishmuseum.org/collectionimages/...           35
# 12  http://www.britishmuseum.org/collectionimages/...           10

# %%
## Add caption length
df['capt_length'] = df['caption.value'].map(lambda x: len(x.split()))
df.tail(5)
# Out:
#                                             caption.value  \
# 782535  Woodblock print. Popular culture. Girl behind ...
# 782538  Woodblock print. Facsimile reproduction. The k...
# 782541  Woodblock print. Itinerant noodle vendor. Acco...
# 782544  Woodblock print. Popular culture. Lady attendi...
# 782547  Woodblock print. Straw dragon on a bamboo pole...
#
#                                               print.value  \
# 782535  http://collection.britishmuseum.org/id/object/...
# 782538  http://collection.britishmuseum.org/id/object/...
# 782541  http://collection.britishmuseum.org/id/object/...
# 782544  http://collection.britishmuseum.org/id/object/...
# 782547  http://collection.britishmuseum.org/id/object/...
#
#                                                 url.value  capt_length
# 782535  http://www.britishmuseum.org/collectionimages/...           35
# 782538  http://www.britishmuseum.org/collectionimages/...           32
# 782541  http://www.britishmuseum.org/collectionimages/...            9
# 782544  http://www.britishmuseum.org/collectionimages/...           10
# 782547  http://www.britishmuseum.org/collectionimages/...           17

# %%
#reset index 
df.reset_index(drop=True)
# Out:
#                                             caption.value  \
# 0       From the animal legend; antelope to left, anot...
# 1       Woodblock print. Giant lantern in the Kaminari...
# 2                 Woodblock print. Spring night at Ginza.
# 3       Le Mont de Neuville; street winding to right b...
# 4       Monochrome woodblock print. Subodai standing. ...
# 5       Colour woodblock print with powdered mica back...
# 6              Woodblock print. Beauty with unrolled obi?
# 7       Colour woodblock print with gold leaf and powd...
# 8       Illustrated book, orihon (folding album), 5 vo...
# 9       Illustrated book, folding album, 2 vols. Varie...
# 10                                       Woodblock print.
# 11      Woodblock print. Woman reading with cat. Colours.
# 12      Woodblock print from an album of 37 sheets. Br...
# 13      Woodblock print from an album of 37 sheets. Gr...
# 14      Woodblock print from an album of 37 sheets. Eb...
# 15      Woodblock print from an album of thirty-seven ...
# 16      Woodblock print from an album of 37 sheets. Pe...
# 17      Woodblock print from an album of 37 sheets. Th...
# 18      Woodblock print from an album of thirty-seven ...
# 19      Woodblock print from an album of 37 sheets. Cr...
# 20      Woodblock print from an album of 37 sheets. Du...
# 21      Woodblock print from an album of 37 sheets. La...
# 22      Woodblock print from an album of 37 sheets. Pe...
# 23      Woodblock print from an album of 37 sheets. Mo...
# 24      Woodblock print from an album of 37 sheets. Lo...
# 25      Woodblock print from an album of 37 sheets. Le...
# 26      Woodblock print from an album of 37 sheets. Pe...
# 27      Woodblock print from an album of 37 sheets. Ev...
# 28      Woodblock print from an album of 37 sheets. Gi...
# 29      Woodblock print from an album of 37 sheets. Th...
# ...                                                   ...
# 255946  Woodblock print. Bijinga. Woman stretching a l...
# 255947  Colour woodblock print, oban. A mother reading...
# 255948  Woodblock print. Bijinga. Girl holding a fan b...
# 255949  Woodblock print. Bijinga. Woman sitting with d...
# 255950  Woodblock print. Bijinga. Hanamurasaki of the ...
# 255951  Woodblock print.History, myth and legend. Warr...
# 255952  Woodblock print. Uki-e. Combining scenes from ...
# 255953  Woodblock print. Deer and pine tree, advertise...
# 255954  Hand-coloured woodblock print, mounted as hang...
# 255955  Woodblock print, hand coloured, mounted as a h...
# 255956  Woodblock print mounted as a hanging scroll. T...
# 255957  Woodblock print. Kabuki. Actor Iwai Hanshiro a...
# 255958  Colour woodblock pillar print, hashira-e. Shid...
# 255959  Woodblock print.Nagasaki-e. Seascape. A Dutch ...
# 255960  Colour woodblock print, Oban. Portrait of the ...
# 255961  Woodblock print. Bijinga. Yosoi of the Matsuba...
# 255962  Colour woodblock print with powdered mica grou...
# 255963  Woodblock print.Classical literature. Love tha...
# 255964  Woodblock print. Bijinga. Hanazuma of the Hyog...
# 255965  Colour woodblock print. The kabuki actor Otani...
# 255966  Woodblock print. Kabuki. Actor Matsumoto Koshi...
# 255967  Woodblock print.Townscape. Masaki after a heav...
# 255968  Woodblock print. Carp leaping up a waterfall. ...
# 255969  Colour woodblock print, one sheet of an oban t...
# 255970  Woodblock print. Bijinga. Courtesan parading i...
# 255971  Woodblock print. Popular culture. Girl behind ...
# 255972  Woodblock print. Facsimile reproduction. The k...
# 255973  Woodblock print. Itinerant noodle vendor. Acco...
# 255974  Woodblock print. Popular culture. Lady attendi...
# 255975  Woodblock print. Straw dragon on a bamboo pole...
#
#                                               print.value  \
# 0       http://collection.britishmuseum.org/id/object/...
# 1       http://collection.britishmuseum.org/id/object/...
# 2       http://collection.britishmuseum.org/id/object/...
# 3       http://collection.britishmuseum.org/id/object/...
# 4       http://collection.britishmuseum.org/id/object/...
# 5       http://collection.britishmuseum.org/id/object/...
# 6       http://collection.britishmuseum.org/id/object/...
# 7       http://collection.britishmuseum.org/id/object/...
# 8       http://collection.britishmuseum.org/id/object/...
# 9       http://collection.britishmuseum.org/id/object/...
# 10      http://collection.britishmuseum.org/id/object/...
# 11      http://collection.britishmuseum.org/id/object/...
# 12      http://collection.britishmuseum.org/id/object/...
# 13      http://collection.britishmuseum.org/id/object/...
# 14      http://collection.britishmuseum.org/id/object/...
# 15      http://collection.britishmuseum.org/id/object/...
# 16      http://collection.britishmuseum.org/id/object/...
# 17      http://collection.britishmuseum.org/id/object/...
# 18      http://collection.britishmuseum.org/id/object/...
# 19      http://collection.britishmuseum.org/id/object/...
# 20      http://collection.britishmuseum.org/id/object/...
# 21      http://collection.britishmuseum.org/id/object/...
# 22      http://collection.britishmuseum.org/id/object/...
# 23      http://collection.britishmuseum.org/id/object/...
# 24      http://collection.britishmuseum.org/id/object/...
# 25      http://collection.britishmuseum.org/id/object/...
# 26      http://collection.britishmuseum.org/id/object/...
# 27      http://collection.britishmuseum.org/id/object/...
# 28      http://collection.britishmuseum.org/id/object/...
# 29      http://collection.britishmuseum.org/id/object/...
# ...                                                   ...
# 255946  http://collection.britishmuseum.org/id/object/...
# 255947  http://collection.britishmuseum.org/id/object/...
# 255948  http://collection.britishmuseum.org/id/object/...
# 255949  http://collection.britishmuseum.org/id/object/...
# 255950  http://collection.britishmuseum.org/id/object/...
# 255951  http://collection.britishmuseum.org/id/object/...
# 255952  http://collection.britishmuseum.org/id/object/...
# 255953  http://collection.britishmuseum.org/id/object/...
# 255954  http://collection.britishmuseum.org/id/object/...
# 255955  http://collection.britishmuseum.org/id/object/...
# 255956  http://collection.britishmuseum.org/id/object/...
# 255957  http://collection.britishmuseum.org/id/object/...
# 255958  http://collection.britishmuseum.org/id/object/...
# 255959  http://collection.britishmuseum.org/id/object/...
# 255960  http://collection.britishmuseum.org/id/object/...
# 255961  http://collection.britishmuseum.org/id/object/...
# 255962  http://collection.britishmuseum.org/id/object/...
# 255963  http://collection.britishmuseum.org/id/object/...
# 255964  http://collection.britishmuseum.org/id/object/...
# 255965  http://collection.britishmuseum.org/id/object/...
# 255966  http://collection.britishmuseum.org/id/object/...
# 255967  http://collection.britishmuseum.org/id/object/...
# 255968  http://collection.britishmuseum.org/id/object/...
# 255969  http://collection.britishmuseum.org/id/object/...
# 255970  http://collection.britishmuseum.org/id/object/...
# 255971  http://collection.britishmuseum.org/id/object/...
# 255972  http://collection.britishmuseum.org/id/object/...
# 255973  http://collection.britishmuseum.org/id/object/...
# 255974  http://collection.britishmuseum.org/id/object/...
# 255975  http://collection.britishmuseum.org/id/object/...
#
#                                                 url.value  capt_length
# 0       http://www.britishmuseum.org/collectionimages/...           12
# 1       http://www.britishmuseum.org/collectionimages/...           10
# 2       http://www.britishmuseum.org/collectionimages/...            6
# 3       http://www.britishmuseum.org/collectionimages/...           35
# 4       http://www.britishmuseum.org/collectionimages/...           10
# 5       http://www.britishmuseum.org/collectionimages/...           22
# 6       http://www.britishmuseum.org/collectionimages/...            6
# 7       http://www.britishmuseum.org/collectionimages/...           24
# 8       http://www.britishmuseum.org/collectionimages/...           31
# 9       http://www.britishmuseum.org/collectionimages/...           11
# 10      http://www.britishmuseum.org/collectionimages/...            2
# 11      http://www.britishmuseum.org/collectionimages/...            7
# 12      http://www.britishmuseum.org/collectionimages/...           18
# 13      http://www.britishmuseum.org/collectionimages/...           16
# 14      http://www.britishmuseum.org/collectionimages/...           22
# 15      http://www.britishmuseum.org/collectionimages/...           13
# 16      http://www.britishmuseum.org/collectionimages/...           18
# 17      http://www.britishmuseum.org/collectionimages/...           18
# 18      http://www.britishmuseum.org/collectionimages/...           21
# 19      http://www.britishmuseum.org/collectionimages/...           15
# 20      http://www.britishmuseum.org/collectionimages/...           16
# 21      http://www.britishmuseum.org/collectionimages/...           15
# 22      http://www.britishmuseum.org/collectionimages/...           18
# 23      http://www.britishmuseum.org/collectionimages/...           24
# 24      http://www.britishmuseum.org/collectionimages/...           18
# 25      http://www.britishmuseum.org/collectionimages/...           19
# 26      http://www.britishmuseum.org/collectionimages/...           19
# 27      http://www.britishmuseum.org/collectionimages/...           20
# 28      http://www.britishmuseum.org/collectionimages/...           19
# 29      http://www.britishmuseum.org/collectionimages/...           18
# ...                                                   ...          ...
# 255946  http://www.britishmuseum.org/collectionimages/...           12
# 255947  http://www.britishmuseum.org/collectionimages/...           27
# 255948  http://www.britishmuseum.org/collectionimages/...           19
# 255949  http://www.britishmuseum.org/collectionimages/...           10
# 255950  http://www.britishmuseum.org/collectionimages/...           15
# 255951  http://www.britishmuseum.org/collectionimages/...           20
# 255952  http://www.britishmuseum.org/collectionimages/...           27
# 255953  http://www.britishmuseum.org/collectionimages/...           12
# 255954  http://www.britishmuseum.org/collectionimages/...           14
# 255955  http://www.britishmuseum.org/collectionimages/...           26
# 255956  http://www.britishmuseum.org/collectionimages/...           13
# 255957  http://www.britishmuseum.org/collectionimages/...           16
# 255958  http://www.britishmuseum.org/collectionimages/...           27
# 255959  http://www.britishmuseum.org/collectionimages/...           30
# 255960  http://www.britishmuseum.org/collectionimages/...           50
# 255961  http://www.britishmuseum.org/collectionimages/...            9
# 255962  http://www.britishmuseum.org/collectionimages/...           26
# 255963  http://www.britishmuseum.org/collectionimages/...           35
# 255964  http://www.britishmuseum.org/collectionimages/...           23
# 255965  http://www.britishmuseum.org/collectionimages/...           14
# 255966  http://www.britishmuseum.org/collectionimages/...           25
# 255967  http://www.britishmuseum.org/collectionimages/...           21
# 255968  http://www.britishmuseum.org/collectionimages/...           10
# 255969  http://www.britishmuseum.org/collectionimages/...           54
# 255970  http://www.britishmuseum.org/collectionimages/...           22
# 255971  http://www.britishmuseum.org/collectionimages/...           35
# 255972  http://www.britishmuseum.org/collectionimages/...           32
# 255973  http://www.britishmuseum.org/collectionimages/...            9
# 255974  http://www.britishmuseum.org/collectionimages/...           10
# 255975  http://www.britishmuseum.org/collectionimages/...           17
#
# [255976 rows x 4 columns]

# %%
#plot occurrences of each length

from collections import Counter
c = Counter(df['capt_length'])
plt.plot(*zip(*sorted(c.items())))
plt.xlim(1,10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3896307d4460> in <module>()
#       3 from collections import Counter
#       4 c = Counter(df['capt_length'])
# ----> 5 plt.plot(*zip(*sorted(c.items())))
#       6 plt.xlim(1,10)
#
# NameError: name 'plt' is not defined

# %%
#There's roughly around 1k of words less than 5. Remove them.
df = df[df['capt_length'] > 5]
df.reset_index(drop=True)
# Out:
#                                             caption.value  \
# 0       From the animal legend; antelope to left, anot...
# 1       Woodblock print. Giant lantern in the Kaminari...
# 2                 Woodblock print. Spring night at Ginza.
# 3       Le Mont de Neuville; street winding to right b...
# 4       Monochrome woodblock print. Subodai standing. ...
# 5       Colour woodblock print with powdered mica back...
# 6              Woodblock print. Beauty with unrolled obi?
# 7       Colour woodblock print with gold leaf and powd...
# 8       Illustrated book, orihon (folding album), 5 vo...
# 9       Illustrated book, folding album, 2 vols. Varie...
# 10      Woodblock print. Woman reading with cat. Colours.
# 11      Woodblock print from an album of 37 sheets. Br...
# 12      Woodblock print from an album of 37 sheets. Gr...
# 13      Woodblock print from an album of 37 sheets. Eb...
# 14      Woodblock print from an album of thirty-seven ...
# 15      Woodblock print from an album of 37 sheets. Pe...
# 16      Woodblock print from an album of 37 sheets. Th...
# 17      Woodblock print from an album of thirty-seven ...
# 18      Woodblock print from an album of 37 sheets. Cr...
# 19      Woodblock print from an album of 37 sheets. Du...
# 20      Woodblock print from an album of 37 sheets. La...
# 21      Woodblock print from an album of 37 sheets. Pe...
# 22      Woodblock print from an album of 37 sheets. Mo...
# 23      Woodblock print from an album of 37 sheets. Lo...
# 24      Woodblock print from an album of 37 sheets. Le...
# 25      Woodblock print from an album of 37 sheets. Pe...
# 26      Woodblock print from an album of 37 sheets. Ev...
# 27      Woodblock print from an album of 37 sheets. Gi...
# 28      Woodblock print from an album of 37 sheets. Th...
# 29      Woodblock print from an album of 37 sheets. Th...
# ...                                                   ...
# 254211  Woodblock print. Bijinga. Woman stretching a l...
# 254212  Colour woodblock print, oban. A mother reading...
# 254213  Woodblock print. Bijinga. Girl holding a fan b...
# 254214  Woodblock print. Bijinga. Woman sitting with d...
# 254215  Woodblock print. Bijinga. Hanamurasaki of the ...
# 254216  Woodblock print.History, myth and legend. Warr...
# 254217  Woodblock print. Uki-e. Combining scenes from ...
# 254218  Woodblock print. Deer and pine tree, advertise...
# 254219  Hand-coloured woodblock print, mounted as hang...
# 254220  Woodblock print, hand coloured, mounted as a h...
# 254221  Woodblock print mounted as a hanging scroll. T...
# 254222  Woodblock print. Kabuki. Actor Iwai Hanshiro a...
# 254223  Colour woodblock pillar print, hashira-e. Shid...
# 254224  Woodblock print.Nagasaki-e. Seascape. A Dutch ...
# 254225  Colour woodblock print, Oban. Portrait of the ...
# 254226  Woodblock print. Bijinga. Yosoi of the Matsuba...
# 254227  Colour woodblock print with powdered mica grou...
# 254228  Woodblock print.Classical literature. Love tha...
# 254229  Woodblock print. Bijinga. Hanazuma of the Hyog...
# 254230  Colour woodblock print. The kabuki actor Otani...
# 254231  Woodblock print. Kabuki. Actor Matsumoto Koshi...
# 254232  Woodblock print.Townscape. Masaki after a heav...
# 254233  Woodblock print. Carp leaping up a waterfall. ...
# 254234  Colour woodblock print, one sheet of an oban t...
# 254235  Woodblock print. Bijinga. Courtesan parading i...
# 254236  Woodblock print. Popular culture. Girl behind ...
# 254237  Woodblock print. Facsimile reproduction. The k...
# 254238  Woodblock print. Itinerant noodle vendor. Acco...
# 254239  Woodblock print. Popular culture. Lady attendi...
# 254240  Woodblock print. Straw dragon on a bamboo pole...
#
#                                               print.value  \
# 0       http://collection.britishmuseum.org/id/object/...
# 1       http://collection.britishmuseum.org/id/object/...
# 2       http://collection.britishmuseum.org/id/object/...
# 3       http://collection.britishmuseum.org/id/object/...
# 4       http://collection.britishmuseum.org/id/object/...
# 5       http://collection.britishmuseum.org/id/object/...
# 6       http://collection.britishmuseum.org/id/object/...
# 7       http://collection.britishmuseum.org/id/object/...
# 8       http://collection.britishmuseum.org/id/object/...
# 9       http://collection.britishmuseum.org/id/object/...
# 10      http://collection.britishmuseum.org/id/object/...
# 11      http://collection.britishmuseum.org/id/object/...
# 12      http://collection.britishmuseum.org/id/object/...
# 13      http://collection.britishmuseum.org/id/object/...
# 14      http://collection.britishmuseum.org/id/object/...
# 15      http://collection.britishmuseum.org/id/object/...
# 16      http://collection.britishmuseum.org/id/object/...
# 17      http://collection.britishmuseum.org/id/object/...
# 18      http://collection.britishmuseum.org/id/object/...
# 19      http://collection.britishmuseum.org/id/object/...
# 20      http://collection.britishmuseum.org/id/object/...
# 21      http://collection.britishmuseum.org/id/object/...
# 22      http://collection.britishmuseum.org/id/object/...
# 23      http://collection.britishmuseum.org/id/object/...
# 24      http://collection.britishmuseum.org/id/object/...
# 25      http://collection.britishmuseum.org/id/object/...
# 26      http://collection.britishmuseum.org/id/object/...
# 27      http://collection.britishmuseum.org/id/object/...
# 28      http://collection.britishmuseum.org/id/object/...
# 29      http://collection.britishmuseum.org/id/object/...
# ...                                                   ...
# 254211  http://collection.britishmuseum.org/id/object/...
# 254212  http://collection.britishmuseum.org/id/object/...
# 254213  http://collection.britishmuseum.org/id/object/...
# 254214  http://collection.britishmuseum.org/id/object/...
# 254215  http://collection.britishmuseum.org/id/object/...
# 254216  http://collection.britishmuseum.org/id/object/...
# 254217  http://collection.britishmuseum.org/id/object/...
# 254218  http://collection.britishmuseum.org/id/object/...
# 254219  http://collection.britishmuseum.org/id/object/...
# 254220  http://collection.britishmuseum.org/id/object/...
# 254221  http://collection.britishmuseum.org/id/object/...
# 254222  http://collection.britishmuseum.org/id/object/...
# 254223  http://collection.britishmuseum.org/id/object/...
# 254224  http://collection.britishmuseum.org/id/object/...
# 254225  http://collection.britishmuseum.org/id/object/...
# 254226  http://collection.britishmuseum.org/id/object/...
# 254227  http://collection.britishmuseum.org/id/object/...
# 254228  http://collection.britishmuseum.org/id/object/...
# 254229  http://collection.britishmuseum.org/id/object/...
# 254230  http://collection.britishmuseum.org/id/object/...
# 254231  http://collection.britishmuseum.org/id/object/...
# 254232  http://collection.britishmuseum.org/id/object/...
# 254233  http://collection.britishmuseum.org/id/object/...
# 254234  http://collection.britishmuseum.org/id/object/...
# 254235  http://collection.britishmuseum.org/id/object/...
# 254236  http://collection.britishmuseum.org/id/object/...
# 254237  http://collection.britishmuseum.org/id/object/...
# 254238  http://collection.britishmuseum.org/id/object/...
# 254239  http://collection.britishmuseum.org/id/object/...
# 254240  http://collection.britishmuseum.org/id/object/...
#
#                                                 url.value  capt_length
# 0       http://www.britishmuseum.org/collectionimages/...           12
# 1       http://www.britishmuseum.org/collectionimages/...           10
# 2       http://www.britishmuseum.org/collectionimages/...            6
# 3       http://www.britishmuseum.org/collectionimages/...           35
# 4       http://www.britishmuseum.org/collectionimages/...           10
# 5       http://www.britishmuseum.org/collectionimages/...           22
# 6       http://www.britishmuseum.org/collectionimages/...            6
# 7       http://www.britishmuseum.org/collectionimages/...           24
# 8       http://www.britishmuseum.org/collectionimages/...           31
# 9       http://www.britishmuseum.org/collectionimages/...           11
# 10      http://www.britishmuseum.org/collectionimages/...            7
# 11      http://www.britishmuseum.org/collectionimages/...           18
# 12      http://www.britishmuseum.org/collectionimages/...           16
# 13      http://www.britishmuseum.org/collectionimages/...           22
# 14      http://www.britishmuseum.org/collectionimages/...           13
# 15      http://www.britishmuseum.org/collectionimages/...           18
# 16      http://www.britishmuseum.org/collectionimages/...           18
# 17      http://www.britishmuseum.org/collectionimages/...           21
# 18      http://www.britishmuseum.org/collectionimages/...           15
# 19      http://www.britishmuseum.org/collectionimages/...           16
# 20      http://www.britishmuseum.org/collectionimages/...           15
# 21      http://www.britishmuseum.org/collectionimages/...           18
# 22      http://www.britishmuseum.org/collectionimages/...           24
# 23      http://www.britishmuseum.org/collectionimages/...           18
# 24      http://www.britishmuseum.org/collectionimages/...           19
# 25      http://www.britishmuseum.org/collectionimages/...           19
# 26      http://www.britishmuseum.org/collectionimages/...           20
# 27      http://www.britishmuseum.org/collectionimages/...           19
# 28      http://www.britishmuseum.org/collectionimages/...           18
# 29      http://www.britishmuseum.org/collectionimages/...           18
# ...                                                   ...          ...
# 254211  http://www.britishmuseum.org/collectionimages/...           12
# 254212  http://www.britishmuseum.org/collectionimages/...           27
# 254213  http://www.britishmuseum.org/collectionimages/...           19
# 254214  http://www.britishmuseum.org/collectionimages/...           10
# 254215  http://www.britishmuseum.org/collectionimages/...           15
# 254216  http://www.britishmuseum.org/collectionimages/...           20
# 254217  http://www.britishmuseum.org/collectionimages/...           27
# 254218  http://www.britishmuseum.org/collectionimages/...           12
# 254219  http://www.britishmuseum.org/collectionimages/...           14
# 254220  http://www.britishmuseum.org/collectionimages/...           26
# 254221  http://www.britishmuseum.org/collectionimages/...           13
# 254222  http://www.britishmuseum.org/collectionimages/...           16
# 254223  http://www.britishmuseum.org/collectionimages/...           27
# 254224  http://www.britishmuseum.org/collectionimages/...           30
# 254225  http://www.britishmuseum.org/collectionimages/...           50
# 254226  http://www.britishmuseum.org/collectionimages/...            9
# 254227  http://www.britishmuseum.org/collectionimages/...           26
# 254228  http://www.britishmuseum.org/collectionimages/...           35
# 254229  http://www.britishmuseum.org/collectionimages/...           23
# 254230  http://www.britishmuseum.org/collectionimages/...           14
# 254231  http://www.britishmuseum.org/collectionimages/...           25
# 254232  http://www.britishmuseum.org/collectionimages/...           21
# 254233  http://www.britishmuseum.org/collectionimages/...           10
# 254234  http://www.britishmuseum.org/collectionimages/...           54
# 254235  http://www.britishmuseum.org/collectionimages/...           22
# 254236  http://www.britishmuseum.org/collectionimages/...           35
# 254237  http://www.britishmuseum.org/collectionimages/...           32
# 254238  http://www.britishmuseum.org/collectionimages/...            9
# 254239  http://www.britishmuseum.org/collectionimages/...           10
# 254240  http://www.britishmuseum.org/collectionimages/...           17
#
# [254241 rows x 4 columns]

# %%
list(df['caption.value'].sample(100))
# Out:
# [u'Portrait of Margaret Wemyss, Countess of Cromartie; three-quarter length standing in front of leafy cliffs at the edge of a pool, holding a spray of star-shaped flowers and berries in right hand, drawing the end of her cloak across her with the other hand, smiling towards the viewer with head tilted towards right shoulder, wearing a loose gown with hair dressed half-up with ringlets over the shoulders.\n\nMezzotint',
#  u'Plate 4: view of the hospital, in medieval castle style with turrets, with the entrance in the left foreground under clock tower with dome and cupola, two figures standing in the terrace between the entrance and front steps from the garden; after Jones.  1826\n\nLithograph',
#  u'A girl standing slightly to left behind an open window, with head tilted to right, looking down at a ring on the sill, touching the curtains with her right hand; roses in foreground at left and right; coat of arms at centre of inscription space; after G S Newton.  1831\n\nEngraving and etching',
#  u'Plate 17; Juno frightened by three Furies throws her hands back, a peacock at her right; from a series of twenty-two engravings\nEngraving',
#  u'Virgin and Child, with the Virgin suckling Christ Child, who lies on a cushion; after Andrea Solario.  1636\n\nEtching',
#  u'Two shepherds, one on horseback with a flock of goats, sheep and a cow walking through a river; trees on either side and in the background. 1799\nEtching',
#  u"View of the river Serchio near Borgo a Mozzano and the bridge Ponte della Maddalena, seen from a hill, with a figure walking below on the right bank; proof illustration to 'The Solace of Song' by Charles Robert Latrobe (London: 1837, after p.196); proof.  1836-1837\n\nWood-engraving on thin paper, with letterpress",
#  u'Portrait of Nicholas Rockox. three-quarter length seated. With a bust of Demosthenes on a table and a view of Antwerp in the background.\nEngraving with touches of black chalk',
#  u'Archer taking aim with a bow and arrow through a window, watched by an elderly man sitting by a low table\n\nWood-engraving, touched working proof',
#  u'Martin Luther with a doctoral cap; bust in right profule set in an ornamental framework.  c.1525\nEngraving',
#  u'Young man, directed towards and facing the front, left hand resting on a book open in front of him, his face illuminated by a single candlestick on the right.  1760\n\nMezzotint',
#  u"Plate 1: The torch-bearers; loosely based on Aldegrever's engraving (NH e.161); two whole-length male figure; the one at left in frontal view; the figure at right in profile to left; from a series of 12 engravings.  1539\n\nEngraving",
#  u'The Virgin and Child; with St Joseph seen through a window behind to left.\n\nEtching',
#  u"Henri of Navarre and Elizabeth I conversing in a room; the queen sits in an armchair at left, Henri on a chair at right; two young women stand beside the queen, a man on the far right; finished state of illustration preceding the first canto of 'L'Henriade', volume I page 1 of Voltaire's 'Collection Compl\xe8te des Oeuvres', 30 vols in-4\xb0 (Geneva, 1768-1774).  c.1768/74\n\nEtching and engraving",
#  u'Trade card of Claessens, bookbinder and gilder; an open book leaning on a closed book on the side, a landscape on the left page, lettering on the right page\n\nEtching on chine coll\xe9',
#  u'View of town on cliffs with ruined castle in centre, seen from banks of river in foreground, a lone figure standing outside buildings on bank at left, watching a rowing boat with three passengers on the water; illustration to the Copperplate Magazine.  1800\n\nEtching and engraving',
#  u'The ancient glacis of Antwerp; a curve in a country road with one poplar to left, to right tree poplars, in the right background a church\n\nEtching with surface tone',
#  u'Portrait of Catherine Hunter after Edward Francis Cunningham; seated at table, half-length in three quarter profile to right, arms crossed, wearing pearls in her hair and fur-trimmed cloak; published state.  22 July 1771\n\nMezzotint',
#  u'A conventional and symbolical arch frames the words here taken as the title. It rests on a rock, a Constitutional Rock, and is surmounted by the figures of Truth with her mirror, Liberty, irradiated, with the cap of Liberty on a staff, and Justice with sword and scales. On the architrave, &c.: Phillips, Architect; Trial by Jury; Public Press; United Exertion. The (clustered) flanking Corinthian columns are inscribed Committee, the word repeated eight times. At the bases, resting respectively on Magna Charta (left) and Law of the Land (right), are Chairman and Treasurer, T. W. Dow and Foundation Laid Feby 26. 1827. by Jas Corder. Four steps leading to the arch are, reading upwards: Subscriptions; Demand of Right; Perseverance; Victory.  January 1828\n\nEtching',
#  u'Lady Jane Grey offered the crown of England; proof before all lettering.  c.1850\nStipple',
#  u'A parish church with low walls and steeply sloping roofs, and a large, squat, square tower to the left, with thick buttresses; in a graveyard with three large square tombs on the right and the thatched roof with a stone chimney between trees in the background on the right.  1843\n\nEtching',
#  u'Copy of medal/coin depicting Edward VI, half length, wearing a plumed cap.\n\nEtching',
#  u'A crowded scene, country folk at a hiring or "Statute" fair. Some dance in a ring, to fiddle, drum, &c. Some throw sticks at objects on posts, or stake their money on various devices. Men swarm up a greasy pole for a leg of mutton and vegetables. The background is formed of booths including that of \'Richardson\'. Fabulous animals and a fat man are depicted on a pyramid of canvases outside a booth. At another booth, which is surmounted by a beribboned hat (? the prize), three yokels are \'Grinning thro Horse Collar\'. There are many tents with flags and signs.  c.1830\n\nHand-coloured etching and aquatint',
#  u'Half-length portrait of a bearded man turned slightly to right; his jacket and shirt sketched in. Second state. 1883\n\nEtching with stipple',
#  u"View from an upper window in Edwards Hussey Delaval's house in Westminster, looking towards the east side of the House of Lords and the east end of the Prince's Chamber; piles of logs, stone and general debris on the floor below, men working on site; illustration from the Antiquities of Westminster. 1807\n\nEtching",
#  u'Sculpted bust of a young man with nearly shoulder-length hair, directed to front, with head turned to look to left, wearing armour decorated with a head in profile, flanked by two full-size figures and a winged creature.  1876\n\nDrypoint',
#  u'Two women in an interior, one standing cradling a small child, the other seated hand one clasping at her necklace.  c.1860-63 (proof)\n\nWood-engraving, heightened with Chinese white',
#  u'Landscape with, in the foreground, men standing on the bank of a river, and fishing with nets; in the distance, cattle, and ruins of a castle\n\nEtching',
#  u'View of the canal looking towards the bridge; a passenger boat crowded with figure sitting or standing in the open top space passing down canal, pulled by two horse from the shore to the right; ifigures strolliing along canalside on the left, some fishing from shore or boats.  1801\n\nEtching and aquatint',
#  u'Studies of the human anatomy; showing the proportions of the male and female human head; a group of children playing with drawing equipment on a frieze below. 1796\nEtching on china paper',
#  u"Headed: 'N\xb0 21.......' Text: 'I Promise to pay to Sir Richd Fillup & Sir Jonathan Crazy, Knts / or Bearer, Ten Centimes, when the Honour of Knighthood shall be / no longer conferred on Swindling City-Tradesmen, or, Lottery Insurers, / but be the reward of Real Merit, True Valour, and Learning, Only. / London, the 16th day of August [? 1810]. For Self, Science, Art & Courage, / Horatio Hardbattle. / Centimes TEN / Entd Lexico Scholastic'. / On the left of the text: enclosed in an oval border, two little men on a round platform stand in the pillory. Inscription: '* Knights of the wood * Such is the exaltation we deserve'. Above: 'When dignity's bestow'd on basest men, / The Private Station is the Post of Honor'. Below: 'Raised by Impudence, / Humbled by Justice!!!'\n\n6 August 1810\n\nEtching with engraved writing",
#  u"View of Wentworth Castle, seen from river, across deer park with a tree in the right foreground, temple on the left of the house, forest in the background; after John Preston Neale; illustration to Neale's 'Views of the seats of noblemen and gentlemen, in England, Wales, Scotland, and Ireland'; proof with artists' names only.  1821\n\nEtching and engraving, printed on chine coll\xe9",
#  u'Fox and North as itinerant musicians, much caricatured, receive plates of broken victuals from a maidservant.  North, very bulky and on a larger scale than Fox, beats a tambourine, he looks downwards, his tongue protruding (or perhaps he has just caught a penny in his mouth). \n\nFox has a large hurdy-gurdy slung across his shoulder and supported on his knee, his other knee is protected from the cobbles of the street by a small four-legged stool. He holds out his hat to receive the food which the girl, who leans out from a street door, is slipping into it from a plate.  21 January 1784\nEtching',
#  u'A seated dog, in profile to left\n\nEtching',
#  u'DRAFT Trade card of Hales, tobacconist',
#  u"Title-page to 'Pharmacopoeia Londinensis' (London, John Marriott, 1618); title in centre; above, the royal coat of arms between two obelisks and beneath a cloud inscribed with the tetragrammaton and from which a hand extends; to the left of the title, Hippocrates, standing, holding a book; to the right of the title, Galen, standing and holding a book; bottom left and right, half length portraits of Mesue and Avicenna; bottom centre, a shield featuring an emblem of two hands clasped above a thistle.\n\nEngraving",
#  u'Portrait of Cardinal de Fleury; half-length, frontal view, after Rigaud; progress proof before letters, printed in yellow ink. 1738\n\nColour mezzotint',
#  u'View of the ancient gate in Rome known as the Arch of Drusus, on the via Appia just inside the Porta S. Sebastiano. 1826\n\nEtching',
#  u'Distant view of Abbotsford House and the surrounding countryside from a hill road; two figures walking in foreground at left; flocks of sheep grazing in a field below at right and on a hill in background; proof illustration to an unidentified publication; after John Preston Neale.  1829\nEtching and engraving on chine coll\xe9',
#  u'Design for a wall-tomb with a sarcophagus; a copy after Radi\nEngraving',
#  u'Plate 100: Armourer; standing inside a workshop, with a firearm in his hands, talking with a man sitting by a table at right; a cityscape with figures seen through the doorwat at left.  1695\n\nEngraving',
#  u"Painting, after Van Loo: a child paints a near naked young girl posed before him at left; Madame de Pompadour's coat of arms in lower margin.  1756\nEtching and engraving",
#  u'DRAFT Trade card of John Lilley, scientific instrument maker',
#  u"Unidentified coat of arms with a two shields and below a skull decorated with an ouboros; above, a crown and 'XP' in a triangle.",
#  u'Portrait of Joseph Marchi after Reynolds (Mannings 1219); half-length facing left, wearing a turban and coat with a fur collar; published state.  1761\n\nMezzotint',
#  u'Bust portrait of Giovanni Francesco Penni, facing half right, after Luigi Agricola\n\nEngraving',
#  u"Portrait; three-quarters length seated to right, looking towards the viewer, elbows on the arms of his chair, a book propped on his knee with his right hand, wearing judge's fur-trimmed robes with bands and wig; after Coslett; state with scratched artists' names only.  1825 \n\nMezzotint on chine coll\xe9",
#  u'The last supper; Christ at centre, a cup in front of him on the table, apostles seated around the table, drapery above them, bread and wine on the floor in the foreground; in an oval; vignette to unidentified publication\n\nEtching',
#  u"A scene from Goldsmith's 'Vicar of Wakefield'; a young woman in 18th century dress wearing a plumed hat, examining a piece of cloth, while the shop keeper leans over his counter on the right, gesturing, and the woman's betrothed stands beside her, watching her; a boy talks to a woman leaning over another counter behind to left; a dog lies asleep in the foreground, beside a stool on which is laid an embroidered cloth and a posy of flowers; after Mulready; scratched open-letter state.  1872\n\nMixed method",
#  u'A bacchante sitting on ground to left with legs outstretched, feeding a child sitting on ground beside her from a vase while stroking his head, an urn with grapes at right; reverse copy after Bovi.  1795\n\nStipple',
#  u'Portrait standing half-length facing front, slightly turned to left, with necklace and pearls decorating her curly hair and embroidered dress, holding wreath of flowers, within oval frame; proof before letters.\n\nMezzotint',
#  u'Plate 6: woman with turban and child, seen from behind, holding hands, and woman with veil, facing front; without number.  1765\n\nEtching',
#  u"Eight naked children, playing blind man's buff; copy in reverse\n\netching",
#  u"The Good Samaritan; a man wearing a fur hat, pouring wine to dress the wounds of a man who has been attacked by robbers, while a black servant supports the victim and the samaritan's horse waist tied to a tree behind; another man passes by in the background to left; with a house in the distance.\n\nMezzotint with some burin",
#  u'View of a street with battle taking place.  c.1847-1854\n\nLithograph printed with beige tone-block',
#  u'Nude Tahitian woman seated in the foreground, another behind, running towards water with raised arms. 1893/4\nWoodcut printed in black and hand-coloured in yellow and blue-grey',
#  u'Two women on a beach; one sitting and holding a comb in her right hand; the other, seen from behind, standing; two other figures, one carrying the other on his back, in background; set within integral frame.  1920\nLithograph in blue ink',
#  u'(For description see other impression).  24 January 1806\n\nEtching',
#  u'Portrait of Arnold Drakenboch, bust turned slightly to the right, facing the viewer; wearing a long curly wig; after Jan Maurits Quinkhard\n\nEngraving and stipple',
#  u'A couple by vase in conservatory, both standing on the right, leaning on the vase in the centre, surrounded by plants.\n\nWood-engraving',
#  u'16: a female herm; plate from the series "Toneel van Sinnebeelden Geopent/Tot dienst van Schilders, Beeldhouders etc door A. Houbraken .II. Deel"; second part of a series of figures depicting emblems and symbols\n\netching',
#  u'Plate 29: The Birds and the Beasts. Several birds at right involved in a fight with several quadrupeds at left, a bat in top left corner choosing the side of the quadrupeds, a castle in right background; large empty lower margin; soiled plate; illustration to John Ogilby\'s "The Fables of Aesop" (London: 1665)\n\nEtching',
#  u"Jacob's dream; Jacob rests on a rock and holds a staff with an apparition of angels on a cloudy ladder beyond; after Heemskerck.  1549\n\nEtching",
#  u'DRAFT Trade card of John Hunter, cabinet maker',
#  u'Rural view a large tree in the foreground surrounded by shrubs, a river at extreme left, another tree on the bank behind, a landscape with hills in the left background.  1770\n\nEtching with engraving',
#  u'A drinking man wearing a hat and shoulder-bag sits near a table, a pipe and some coins lay on the table, to left a window-sill with jug\n\nEtching',
#  u'River view with several sloops with their mainsails set at centre, two smaller rowing boats in foreground, trees at right; a facsimile of a drawing by Aelbert Cuyp; from a series of 105 facsimiles published by Christian Josi as a continuation of Ploos van Amstel\'s publication; illustration to Josi\'s "Collection d\'imitations de dessins" (London: 1821).\nCrayon-manner in Ploos van Amstel\'s technique with additional hand-colouring\n\nVerso: Coat of arms of Ploos van Amstel\n\nCrayon-manner in Ploos van Amstel\'s technique',
#  u'Interior of a gothic church, looking through a tall nave towards the altar where a priest is conducting a service; a statue of Virgin and Child at the corner of the left wall with arched windows, and the far end wall with a rose window and a painting; further eight prayers below the altar; after William Henry Bartlett, proof before letters, touched, with an instruction for a correction.\n\nEtching, printed on chine coll\xe9, touched with graphite',
#  u'The Colosseum as seen in its present ruined state; first state before the address of Lafrery\nEngraving',
#  u'View on the River Lea, a man fishing in foreground, another with fishing pole crossing the bridge to the left; the tavern across the river; a vignette. 1821\n\nEtching',
#  u'Portraits; one man on the right standing in profile, talking to the other, who holds a cane and turns his head to the other, both wearing dark coats and tricorns; with a tree on a mound behind to right.  1787\n\nEtching with some stipple',
#  u'The rat-catcher; group of figures at cottage doorway; pedlar holding tall cage, boy beside him with box, conversing with old man at gate; copy in reverse after Rembrandt.  1768\n\nEtching',
#  u"Tail-piece, a bird perched on a tree branch, looking down at a snail at bottom right which climbs the tree trunk, in an oval; proof illustration to 'Poetical Works of Lord Byron' edited by William Michael Rossetti (London: 1870, E. Moxon, Son & Co).  1870\n\nWood-engraving",
#  u'William Gibbs McNeill Whistler, whole-length, sitting in an arm-chair with a loose cover and holding a glass in his right hand.  1894\nTransfer lithograph on thin, transparent transfer paper; chine appliqu\xe9',
#  u'Workman sitting at table sleeping, his head resting on his arms.  1877-90?\nDrypoint, with light surface tone',
#  u"A street scene; a stout hackney coachman seizes by the collar a tall, lean French barber, who deprecatingly holds out an empty pocket. The barber is fashionably dressed with ruffled shirt; a comb and scissors project from his waistcoat pocket; other tools of his trade have fallen to the ground. The coachman wears a round hat in which are two tickets, one '102 N', showing the number of his coach; there are holes in his coat, waistcoat, and stocking. Behind him (left) is his coach. On the opposite side of the road (right) are two amused spectators: a sailor wearing a round hat and striped trousers, and a fat oyster-woman holding a little girl on one arm; a knife hangs from her waist, and behind her on a bench is a basket of oysters. They stand outside an alehouse, indicated by the sign of chequers and the words London Porter on the shutter of an open sash-window, from which two men are leaning; the dial of a clock inside the room shows that it is five o'clock. Large brick houses receding in perspective complete the background.  Beneath the title is engraved:\n\n\n\n'Pay me my Fare and be damn'd to you. \n\nMe ad only von Sixpence port my Honare.'  1784\n\nHand-coloured mezzotint",
#  u'View in courtyard of hospital, with statue on plinth surrounded by iron railings; a few figures in court.\n\nSteel engraving',
#  u'Portrait of Jan Brueghel I, half-length, facing the viewer, wearing a ruff\nEtching',
#  u'Libra reclining in a carriage, playing a tambourine, a child with scales containing bunches of grapes over his shoulders balances on one foot beside her, the chariot pulled by two tiger-like animals, identified in the inscription as Ariadne and Faun; after Edward Francis Burney, from a series of the months.  1808\n\nStipple and etching',
#  u'Plate 89, no 44; satire showing Casimir Perier brandishing a whip and threatening submissive dogs symbolizing deputies; behind him, another man holding a bell and calling to order another group of dogs; beyond at centre, a staircase leading to a broken door and a poster adverstising that the trainer can tame any kind of animal.  1st September 1831\nLithograph',
#  u'Young woman asleep reclined on a divan, her head in profile resting on her right shoulder, wearing classical draperies tied under her breast, with veil covering curly hair; a book has fallen from her left hand to the floor on r; cupid holding bow flying above on l, pillar with inscription in Greek in the background, leaves and pair of butterflies in the foreground; before letters.  1780/90\n\nEtching, printed in sepia ink',
#  u'Four stags and a doe in a landscape;  plate 41 of the series. 1778\nEtching',
#  u"Two bust portraits in oval frames, better characterized than is usual in this series. They illustrate 'Histories of the T\xeate-\xe0-T\xeate annexed; . . .'. 1 June 1780\nEtching",
#  u"View of the Bass Rock from the coast, with three fishing boats in foreground, and lobster traps lying on rocks at left; within a rectangular border; illustration to Ayton's 'Voyage round Great Britain', vol. VI.  1822\n\nAquatint and some etching with hand-colouring",
#  u"Woman sitting in armchair and tying a ribbon around her son's hat; within oval, with coat of arms in lower margin; proof before letter, but with names of producers and title.  1784\nEngraving",
#  u'Leda bathing with a swan; another nude figure with an attendant behind her; detail after Correggio\nEtching and engraving',
#  u'Crowned Death sitting at the throne on the left, in profile to right, sceptre in his left hand; five figures on the right kneeling and bowing towards him; after Strang.  1901\n\nChiaroscuro woodcut from two blocks in brown and black',
#  u'Plate 29: two figures fishing at a river in the foreground, one seated and the other standing, a bridge in the right middle distance, a side view of the house in the left background; after Sandby; published state.  1777\n\nEtching',
#  u'Portrait of unidentified woman, half-length to left, wearing hat and fur-trimmed coat. 1925\nEtching',
#  u'The Departure, 1854; scene in a harbour, with a woman and three children saying good-bye to a soldier departing for the Crimean War; soldiers marching behind, a group of men waving their top hats at left; masts of ships seen in background; illustration to an unidentified publication; after George Housman Thomas.\n\nWood-engraving',
#  u"A country barber, his assistant, and a boy, are engaged in shaving and wig-dressing. An elderly rustic sits full-face and well-lathered in an arm-chair in the centre of the shop, while a lean and tattered barber holds the bowl. A stout farmer in top-boots (left) with a stubbly face dubiously contemplates a wig, which he holds on a tall wig-block. On the right a fat barber painfully shaves an old man, while a younger customer stanches a cut over a basin. A young boy in front of them holds two elaborately curled legal wigs. A long judge's wig, uncurled, hangs from a wig-block. Behind (left) a prim, elderly man in a newly dressed wig adjusts his neck-cloth at a small mirror; a coachman in back view puts on his tightly curled wig. There are also two dogs, two cats, a magpie taking part of a wig from a box on the floor, and another bird in a cage. Above the door (right) are fishing-rods and a creel. On the wall are four prints: a naval battle (framed); a view of the 'County Gaol'; an execution scene; and a skeleton fiddling to exulting demons. There is also 'A Calendar of the Prisoners to be Tried. . . '. The room is ramshackle with a casement window, bricks showing through the plaster. From the roof hang a ham and a bundle of turnips and carrots.\n\n9 January 1818\n\nEtching and roulette",
#  u'Christ showing a little child as the emblem of heaven, seated in the centre with his back against a pillar, his left hand raised and pointing to heaven, his right holding the hand of the infant standing on the ledge beside him, held up by two women; a crowd of men surrounding; trees through the arch behind; after Benjamin West (Staley 325).  1822\n\nEngraving on chine coll\xe9',
#  u"From a set of six plates illustrating the life of J. P. Kemble, 'Black Jack'. After the title: Blackjack commenced Stroller, and not being able to pay his rent in Staffordshire annoyed his dying Landd in such a Cruel manner with a Large Top which he borrowed that the people were glad to get rid of him without Payment. NB it was about this time that his Washerwoman refused to give him his shirt till he had settled the immense sum of 15 Pence. !!!\u2014\n\nKemble, in (tattered) shirt-sleeves, furiously whips a big top on the boarded floor of a ramshackle attic. A thin elderly woman, standing by a doorway, holds up her hands in horror. A fire burns in a rough fireplace; on this a flat-iron is heating, and tattered stockings and a glove hang on a cord. A basin with soap-suds and washing stands on a stool. Small coal is heaped on the ground by the fire-place with a riddle for cinders, and a bellows. On a shelf over the fireplace are two books, a cup and saucer, and a small candle in a bottle, with (pinned up) a Bill for Lodgings. On the wall is a play-bill: Beaux Strategem [Farquhar] to which will . . . The Cheats of Scapin [Otway after Moli\xe8re]. On the ground is an open book: We Fly by Night [see No. 10673] Poor Gentn [Colman, 1802] & &. \n\nNov 1809\n\nHand-coloured etching with stipple",
#  u'View of the hermitage in the middle distance, in front of which a couple strolling escorted by a hermit, further figures arriving from the right, seen across clearing, an artist in the centre foreground sketching, a man on the right whipping his donkey, trees and bushes on the left, volcanic Mount Vesuvius in the left background, a bay in the right, Capri Island on the horizon.  1818\n\nLithograph',
#  u"Representation of Septimius Severus's Wall vertically to right, with engraved description below; to left, maps of the Roman garrisons, with their engraved list below; impression pasted onto sheet of paper under a related print of similar format.  \nEtching and engraving",
#  u"The fable of Hercules and the peasant; a peasant sitting in the foreground at right, throwing up his hands in fright as he is admonished by Hercules, sitting in the clouds high above; behind, a peasant with a whip exhorting his horses, one carrying a man, to drag a heavily laden wagon out of the water in which it is stuck; coastal landscape beyond, with castle in distance at left, a town at right; illustration to John Ogilby, 'The Fables of \xc6sop', vol. 1, 3rd edition (London, 1673).  1673\n\nEtching, illustration to volume bound in brown leather, the spine stamped in gold, with marbled endpapers",
#  u"Border with the four Evangelists (in the corners in circles) and twelve scenes for the life of Christ (in ovals). From top left corner, clockwise: St Mark with a winged lion, the annunciation, the resurrection of Christ, St Luke with bull, Christ on the cross, Christ before Pilate, Christ before Caiaphas, Christ on the Mount of Olives, St John with an eagle, the last supper, multiplication of the loaves and fish, St Matthew with an angel, the baptism of Christ, Christ among the doctors, flight into Egypt and the nativity; letterpress in black and red in centre of border and on verso; after Pieter van den Borcht; illustration to 'Missale Romanum' (Antwerp, 1574)\n\nWoodcut from sixteen separate woodblocks",
#  u'View of the Custom House on Lower Thames Street in London, as designed by Smirke; seen from the Thames; the masts of sailing ships in water to the right; a vignette.\n\nWood-engraving',
#  u'Virgin; rays of light eminating from upturned palms, with serpent coiled around feet.  1920\nColour woodcut, printed in black, red, green and yellow',
#  u'A broadside on the Popish Plot, with an engraving showing three lines of a procession ending, at the top, in Fleet Street with an effigy of the Pope being pushed on to a bonfire in front of Temple Bar surrounded by jubilant crowds. The procession winds its way across two other levels led by a group of whifflers with flaming torches clearing the way, followed by a bellman crying "Remember Justice Godfrey", then by a horseman dressed as a Jesuit supporting an effigy of Sir Edmund Berry Godrey, a Roman Catholic priest offering indulgences for sale, another priest carrying a large cross, groups of friars and monks, Jesuits with bloody daggers, a group of musicians playing trumpets and trombones, bishops, cardinals, the "pope\'s physician" holding a urinal (intended for Sir George Wakeman) and finally an effigy of the pope enthroned, two small boys holding flags with a cross and four daggers in front of him, a crown at his feet and the devil whispering in his ear, on a platform propelled aloft by men whose feet can be glimpsed beneath drapery at the side. Engraved inscription and title, and with letterpress with lengthy explanatory description of the event in four columns including verses mocking Cardinal Howard. (London, Newman and Lee: 1680)']

# %%
from dateutil.parser import parse

def is_date(string):
    try: 
        parse(string)
        return True
    except (TypeError, ValueError):
        return False

# %%
# We will extract the date + the material from the description and put into another column. 

is_date_ct = 0
got_material = 0

def stripExtras(capt):
    global is_date_ct
    global got_material
    arr = capt['caption.value'].split('\n')
    mat = 'n/a'
    orig = capt['caption.value'].strip()
    if len(arr) > 1: 
        mat = arr[-1]
        orig = '\n'.join(arr[:-1]).strip()
        got_material+=1
        
    arr = orig.split('.')
    date = 'n/a'
    if len(arr) > 1 and len(arr[-1]) > 0:
        if (is_date(arr[-1])):
            is_date_ct += 1
            date = arr[-1]
            orig = '.'.join(arr[:-1]).strip()       
        
    return pd.Series([orig, mat, date])

# def stripDates(capt):
#     #print capt
#     arr = capt['caption.value'].split('.')
#     res = 'n/a'
#     orig = capt['caption.value'].strip()
#     if len(arr) > 1:
#         print "Date: ", arr[-1]
#         print "\n\n"
#         #if (is_date(arr[-1])):
#         #    res = arr[-1]
#         #    orig = '.'.join(arr[:-1]).strip()
        
#    return pd.Series([orig, res])

df[['caption.value_cleaned', 'ext_dates', 'ext_materials']] = df.apply(stripExtras, axis=1)
df.head(10)
# Out:
#                                         caption.value  \
# 0   From the animal legend; antelope to left, anot...
# 3   Woodblock print. Giant lantern in the Kaminari...
# 6             Woodblock print. Spring night at Ginza.
# 9   Le Mont de Neuville; street winding to right b...
# 12  Monochrome woodblock print. Subodai standing. ...
# 15  Colour woodblock print with powdered mica back...
# 18         Woodblock print. Beauty with unrolled obi?
# 21  Colour woodblock print with gold leaf and powd...
# 24  Illustrated book, orihon (folding album), 5 vo...
# 27  Illustrated book, folding album, 2 vols. Varie...
#
#                                           print.value  \
# 0   http://collection.britishmuseum.org/id/object/...
# 3   http://collection.britishmuseum.org/id/object/...
# 6   http://collection.britishmuseum.org/id/object/...
# 9   http://collection.britishmuseum.org/id/object/...
# 12  http://collection.britishmuseum.org/id/object/...
# 15  http://collection.britishmuseum.org/id/object/...
# 18  http://collection.britishmuseum.org/id/object/...
# 21  http://collection.britishmuseum.org/id/object/...
# 24  http://collection.britishmuseum.org/id/object/...
# 27  http://collection.britishmuseum.org/id/object/...
#
#                                             url.value  capt_length  \
# 0   http://www.britishmuseum.org/collectionimages/...           12
# 3   http://www.britishmuseum.org/collectionimages/...           10
# 6   http://www.britishmuseum.org/collectionimages/...            6
# 9   http://www.britishmuseum.org/collectionimages/...           35
# 12  http://www.britishmuseum.org/collectionimages/...           10
# 15  http://www.britishmuseum.org/collectionimages/...           22
# 18  http://www.britishmuseum.org/collectionimages/...            6
# 21  http://www.britishmuseum.org/collectionimages/...           24
# 24  http://www.britishmuseum.org/collectionimages/...           31
# 27  http://www.britishmuseum.org/collectionimages/...           11
#
#                                 caption.value_cleaned  \
# 0   From the animal legend; antelope to left, anot...
# 3   Woodblock print. Giant lantern in the Kaminari...
# 6             Woodblock print. Spring night at Ginza.
# 9   Le Mont de Neuville; street winding to right b...
# 12  Monochrome woodblock print. Subodai standing. ...
# 15  Colour woodblock print with powdered mica back...
# 18         Woodblock print. Beauty with unrolled obi?
# 21  Colour woodblock print with gold leaf and powd...
# 24  Illustrated book, orihon (folding album), 5 vo...
# 27  Illustrated book, folding album, 2 vols. Varie...
#
#                                         ext_dates ext_materials
# 0                                         Woodcut          1912
# 3                                             n/a           n/a
# 6                                             n/a           n/a
# 9   Charcoal (?), with watercolour, over monotype          1899
# 12                                            n/a           n/a
# 15                                            n/a           n/a
# 18                                            n/a           n/a
# 21                                            n/a           n/a
# 24                                            n/a           n/a
# 27                                            n/a           n/a

# %%
print float(is_date_ct)/len(df)
print float(got_material)/len(df)

#mistake
df.rename(columns = {'ext_dates': 'materials'}, inplace = True)
df.rename(columns = {'ext_materials': 'dates'}, inplace = True)
# Out:
# 0.486805825968
# 0.921739609268

# %%
list(df.sample(10)['caption.value_cleaned'])
# Out:
# [u"Portrait of the actor John Fawcett, in character as Caleb Quotem, in Lee's 'Throw Physic to the Dogs'; bust, looking upwards to the right, wearing wig and embroidered waistcoat; in oval; after De Wilde",
#  u'(For description see other impression)',
#  u'No.15: a tall young officer wearing a small-sword and holding a pike',
#  u'Portrait of the medallist Joseph Roettier, half-length; in an oval; fourth state with extended inscription in cartouche below portrait; after Nicolas de Largilli\xe8re',
#  u'Portrait of French dramatist Cr\xe9billon, bust-length, in profile to the right, on dark ground and in oval frame; tablet in the lower part',
#  u"Portrait of a woman, probably Emma Johnston, the artist's wife, seen almost whole-length, sleeping in a chair.  c",
#  u'Portrait of Jacob Roelants, nearly half-length to right, looking towards the viewer; wearing a  skull cap, ruff, dark doublet and wide ribbon for an order around his neck; in ornate frame, coat of arms with crest and cartouche for inscription below; second state',
#  u'Woodblock print, oban tate-e. Sumo warrior Onigadake Tetsuemon.',
#  u'A barn with an apex roof and small casement windows, among trees, in parkland, with a man and a dog walking on the left and the bend of a river in the foreground.',
#  u'Portrait of Rembrandt as a falconer, bust directed to left but looking at the viewer, with a falcon perched on his right hand; first state with foul biting; after Rembrandt (?)']

# %%
start = time.time()

#use regex to extract out parentehsis stuff
has_paren_ct = 0

import re
def stripParen(input):
    global has_paren_ct
    s = input['caption.value_cleaned']
    out = re.sub('\(.*?\)', '', s).strip()
    out = re.sub('\[.*?\]', '', out).strip()
    if s != out:
        has_paren_ct += 1
    return pd.Series([out])


df[['caption.value_cleaned2']] = df.apply(stripParen, axis=1)
print list(df.head(5)['caption.value_cleaned'])
print list(df.head(5)['caption.value_cleaned2'])
print "Time:" + str(time.time() - start)
print "Percentage affected:" + str(float(has_paren_ct)/len(df))
# Out:
# [u'From the animal legend; antelope to left, another(?) lying centre', u'Woodblock print. Giant lantern in the Kaminari-mon of Senso-ji temple.', u'Woodblock print. Spring night at Ginza.', u'Le Mont de Neuville; street winding to right beyond, flanked by buildings on both sides, at right figure in doorway and beyond figure standing in middle of road', u'Monochrome woodblock print. Subodai standing. Signed, sealed, inscribed and marked.']
# [u'From the animal legend; antelope to left, another lying centre', u'Woodblock print. Giant lantern in the Kaminari-mon of Senso-ji temple.', u'Woodblock print. Spring night at Ginza.', u'Le Mont de Neuville; street winding to right beyond, flanked by buildings on both sides, at right figure in doorway and beyond figure standing in middle of road', u'Monochrome woodblock print. Subodai standing. Signed, sealed, inscribed and marked.']
# Time:77.8564760685
# Percentage affected:0.193340177233

# %%
print list(df[6000:6010]['caption.value_cleaned'])
print list(df[6000:6010]['caption.value_cleaned2'])
# Out:
# [u"Plate V: Joseph, wearing a loin-cloth and shackled, stands gesticulating before Pharaoh and his queen, enthroned with a harp player kneeling beside them at r; two guards, holding Joseph's chains, and an ibis at left", u'Business card for the mould-maker Malzieux; with decorative border around inscription, of foliage, casts and tools, figures and animals', u'Woman standing at a window, whole-length; wearing very full skirts.', u'View over rolling landscape to town, rright, with tree to left', u'Woman standing at a window, whole-length; wearing very full skirts.', u'Sheet 21 (sig. l): the page is divided into two halves, in the upper compartment God is adored by angels and kings, below the temple of God (titled) is placed above the ark of the covenant, next to wwhich two angels are swinging censers; inscriptions', u'Hunting scene; four horsemen in medieval costume in the background, with a fox chased by hound in the foreground', u'A Gothic tabernacle, shown in elevation and (on a separate plate) in groundplan', u'Kissing couple lying on a bed', u'Woman, whole-length; wearing full skirts.']
# [u"Plate V: Joseph, wearing a loin-cloth and shackled, stands gesticulating before Pharaoh and his queen, enthroned with a harp player kneeling beside them at r; two guards, holding Joseph's chains, and an ibis at left", u'Business card for the mould-maker Malzieux; with decorative border around inscription, of foliage, casts and tools, figures and animals', u'Woman standing at a window, whole-length; wearing very full skirts.', u'View over rolling landscape to town, rright, with tree to left', u'Woman standing at a window, whole-length; wearing very full skirts.', u'Sheet 21 : the page is divided into two halves, in the upper compartment God is adored by angels and kings, below the temple of God  is placed above the ark of the covenant, next to wwhich two angels are swinging censers; inscriptions', u'Hunting scene; four horsemen in medieval costume in the background, with a fox chased by hound in the foreground', u'A Gothic tabernacle, shown in elevation and  in groundplan', u'Kissing couple lying on a bed', u'Woman, whole-length; wearing full skirts.']

# %%
store = pd.HDFStore('/data/captioning/bm_data_clean.h5')

# %%
df_to_store = df[['print.value', 'url.value', 'caption.value_cleaned2', 'materials', 'dates']]
df_to_store.head(5)
# Out:
#                                           print.value  \
# 0   http://collection.britishmuseum.org/id/object/...
# 3   http://collection.britishmuseum.org/id/object/...
# 6   http://collection.britishmuseum.org/id/object/...
# 9   http://collection.britishmuseum.org/id/object/...
# 12  http://collection.britishmuseum.org/id/object/...
#
#                                             url.value  \
# 0   http://www.britishmuseum.org/collectionimages/...
# 3   http://www.britishmuseum.org/collectionimages/...
# 6   http://www.britishmuseum.org/collectionimages/...
# 9   http://www.britishmuseum.org/collectionimages/...
# 12  http://www.britishmuseum.org/collectionimages/...
#
#                                caption.value_cleaned2  \
# 0   From the animal legend; antelope to left, anot...
# 3   Woodblock print. Giant lantern in the Kaminari...
# 6             Woodblock print. Spring night at Ginza.
# 9   Le Mont de Neuville; street winding to right b...
# 12  Monochrome woodblock print. Subodai standing. ...
#
#                                         materials  dates
# 0                                         Woodcut   1912
# 3                                             n/a    n/a
# 6                                             n/a    n/a
# 9   Charcoal (?), with watercolour, over monotype   1899
# 12                                            n/a    n/a

# %%
store['df'] = df_to_store.rename(index=str, columns={'caption.value_cleaned2': 'captions'}).reset_index(drop=True)
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2885: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->['print.value', 'url.value', 'captions', 'materials', 'dates']]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
store['df']
# Out:
#                                               print.value  \
# 0       http://collection.britishmuseum.org/id/object/...
# 1       http://collection.britishmuseum.org/id/object/...
# 2       http://collection.britishmuseum.org/id/object/...
# 3       http://collection.britishmuseum.org/id/object/...
# 4       http://collection.britishmuseum.org/id/object/...
# 5       http://collection.britishmuseum.org/id/object/...
# 6       http://collection.britishmuseum.org/id/object/...
# 7       http://collection.britishmuseum.org/id/object/...
# 8       http://collection.britishmuseum.org/id/object/...
# 9       http://collection.britishmuseum.org/id/object/...
# 10      http://collection.britishmuseum.org/id/object/...
# 11      http://collection.britishmuseum.org/id/object/...
# 12      http://collection.britishmuseum.org/id/object/...
# 13      http://collection.britishmuseum.org/id/object/...
# 14      http://collection.britishmuseum.org/id/object/...
# 15      http://collection.britishmuseum.org/id/object/...
# 16      http://collection.britishmuseum.org/id/object/...
# 17      http://collection.britishmuseum.org/id/object/...
# 18      http://collection.britishmuseum.org/id/object/...
# 19      http://collection.britishmuseum.org/id/object/...
# 20      http://collection.britishmuseum.org/id/object/...
# 21      http://collection.britishmuseum.org/id/object/...
# 22      http://collection.britishmuseum.org/id/object/...
# 23      http://collection.britishmuseum.org/id/object/...
# 24      http://collection.britishmuseum.org/id/object/...
# 25      http://collection.britishmuseum.org/id/object/...
# 26      http://collection.britishmuseum.org/id/object/...
# 27      http://collection.britishmuseum.org/id/object/...
# 28      http://collection.britishmuseum.org/id/object/...
# 29      http://collection.britishmuseum.org/id/object/...
# ...                                                   ...
# 254211  http://collection.britishmuseum.org/id/object/...
# 254212  http://collection.britishmuseum.org/id/object/...
# 254213  http://collection.britishmuseum.org/id/object/...
# 254214  http://collection.britishmuseum.org/id/object/...
# 254215  http://collection.britishmuseum.org/id/object/...
# 254216  http://collection.britishmuseum.org/id/object/...
# 254217  http://collection.britishmuseum.org/id/object/...
# 254218  http://collection.britishmuseum.org/id/object/...
# 254219  http://collection.britishmuseum.org/id/object/...
# 254220  http://collection.britishmuseum.org/id/object/...
# 254221  http://collection.britishmuseum.org/id/object/...
# 254222  http://collection.britishmuseum.org/id/object/...
# 254223  http://collection.britishmuseum.org/id/object/...
# 254224  http://collection.britishmuseum.org/id/object/...
# 254225  http://collection.britishmuseum.org/id/object/...
# 254226  http://collection.britishmuseum.org/id/object/...
# 254227  http://collection.britishmuseum.org/id/object/...
# 254228  http://collection.britishmuseum.org/id/object/...
# 254229  http://collection.britishmuseum.org/id/object/...
# 254230  http://collection.britishmuseum.org/id/object/...
# 254231  http://collection.britishmuseum.org/id/object/...
# 254232  http://collection.britishmuseum.org/id/object/...
# 254233  http://collection.britishmuseum.org/id/object/...
# 254234  http://collection.britishmuseum.org/id/object/...
# 254235  http://collection.britishmuseum.org/id/object/...
# 254236  http://collection.britishmuseum.org/id/object/...
# 254237  http://collection.britishmuseum.org/id/object/...
# 254238  http://collection.britishmuseum.org/id/object/...
# 254239  http://collection.britishmuseum.org/id/object/...
# 254240  http://collection.britishmuseum.org/id/object/...
#
#                                                 url.value  \
# 0       http://www.britishmuseum.org/collectionimages/...
# 1       http://www.britishmuseum.org/collectionimages/...
# 2       http://www.britishmuseum.org/collectionimages/...
# 3       http://www.britishmuseum.org/collectionimages/...
# 4       http://www.britishmuseum.org/collectionimages/...
# 5       http://www.britishmuseum.org/collectionimages/...
# 6       http://www.britishmuseum.org/collectionimages/...
# 7       http://www.britishmuseum.org/collectionimages/...
# 8       http://www.britishmuseum.org/collectionimages/...
# 9       http://www.britishmuseum.org/collectionimages/...
# 10      http://www.britishmuseum.org/collectionimages/...
# 11      http://www.britishmuseum.org/collectionimages/...
# 12      http://www.britishmuseum.org/collectionimages/...
# 13      http://www.britishmuseum.org/collectionimages/...
# 14      http://www.britishmuseum.org/collectionimages/...
# 15      http://www.britishmuseum.org/collectionimages/...
# 16      http://www.britishmuseum.org/collectionimages/...
# 17      http://www.britishmuseum.org/collectionimages/...
# 18      http://www.britishmuseum.org/collectionimages/...
# 19      http://www.britishmuseum.org/collectionimages/...
# 20      http://www.britishmuseum.org/collectionimages/...
# 21      http://www.britishmuseum.org/collectionimages/...
# 22      http://www.britishmuseum.org/collectionimages/...
# 23      http://www.britishmuseum.org/collectionimages/...
# 24      http://www.britishmuseum.org/collectionimages/...
# 25      http://www.britishmuseum.org/collectionimages/...
# 26      http://www.britishmuseum.org/collectionimages/...
# 27      http://www.britishmuseum.org/collectionimages/...
# 28      http://www.britishmuseum.org/collectionimages/...
# 29      http://www.britishmuseum.org/collectionimages/...
# ...                                                   ...
# 254211  http://www.britishmuseum.org/collectionimages/...
# 254212  http://www.britishmuseum.org/collectionimages/...
# 254213  http://www.britishmuseum.org/collectionimages/...
# 254214  http://www.britishmuseum.org/collectionimages/...
# 254215  http://www.britishmuseum.org/collectionimages/...
# 254216  http://www.britishmuseum.org/collectionimages/...
# 254217  http://www.britishmuseum.org/collectionimages/...
# 254218  http://www.britishmuseum.org/collectionimages/...
# 254219  http://www.britishmuseum.org/collectionimages/...
# 254220  http://www.britishmuseum.org/collectionimages/...
# 254221  http://www.britishmuseum.org/collectionimages/...
# 254222  http://www.britishmuseum.org/collectionimages/...
# 254223  http://www.britishmuseum.org/collectionimages/...
# 254224  http://www.britishmuseum.org/collectionimages/...
# 254225  http://www.britishmuseum.org/collectionimages/...
# 254226  http://www.britishmuseum.org/collectionimages/...
# 254227  http://www.britishmuseum.org/collectionimages/...
# 254228  http://www.britishmuseum.org/collectionimages/...
# 254229  http://www.britishmuseum.org/collectionimages/...
# 254230  http://www.britishmuseum.org/collectionimages/...
# 254231  http://www.britishmuseum.org/collectionimages/...
# 254232  http://www.britishmuseum.org/collectionimages/...
# 254233  http://www.britishmuseum.org/collectionimages/...
# 254234  http://www.britishmuseum.org/collectionimages/...
# 254235  http://www.britishmuseum.org/collectionimages/...
# 254236  http://www.britishmuseum.org/collectionimages/...
# 254237  http://www.britishmuseum.org/collectionimages/...
# 254238  http://www.britishmuseum.org/collectionimages/...
# 254239  http://www.britishmuseum.org/collectionimages/...
# 254240  http://www.britishmuseum.org/collectionimages/...
#
#                                                  captions  \
# 0       From the animal legend; antelope to left, anot...
# 1       Woodblock print. Giant lantern in the Kaminari...
# 2                 Woodblock print. Spring night at Ginza.
# 3       Le Mont de Neuville; street winding to right b...
# 4       Monochrome woodblock print. Subodai standing. ...
# 5       Colour woodblock print with powdered mica back...
# 6              Woodblock print. Beauty with unrolled obi?
# 7       Colour woodblock print with gold leaf and powd...
# 8       Illustrated book, orihon , 5 vols . Instructio...
# 9       Illustrated book, folding album, 2 vols. Varie...
# 10      Woodblock print. Woman reading with cat. Colours.
# 11      Woodblock print from an album of 37 sheets. Br...
# 12      Woodblock print from an album of 37 sheets. Gr...
# 13      Woodblock print from an album of 37 sheets. Eb...
# 14      Woodblock print from an album of thirty-seven ...
# 15      Woodblock print from an album of 37 sheets. Pe...
# 16      Woodblock print from an album of 37 sheets. Th...
# 17      Woodblock print from an album of thirty-seven ...
# 18      Woodblock print from an album of 37 sheets. Cr...
# 19      Woodblock print from an album of 37 sheets. Du...
# 20      Woodblock print from an album of 37 sheets. La...
# 21      Woodblock print from an album of 37 sheets. Pe...
# 22      Woodblock print from an album of 37 sheets. Mo...
# 23      Woodblock print from an album of 37 sheets. Lo...
# 24      Woodblock print from an album of 37 sheets. Le...
# 25      Woodblock print from an album of 37 sheets. Pe...
# 26      Woodblock print from an album of 37 sheets. Ev...
# 27      Woodblock print from an album of 37 sheets. Gi...
# 28      Woodblock print from an album of 37 sheets. Th...
# 29      Woodblock print from an album of 37 sheets. Th...
# ...                                                   ...
# 254211  Woodblock print. Bijinga. Woman stretching a l...
# 254212  Colour woodblock print, oban. A mother reading...
# 254213  Woodblock print. Bijinga. Girl holding a fan b...
# 254214  Woodblock print. Bijinga. Woman sitting with d...
# 254215  Woodblock print. Bijinga. Hanamurasaki of the ...
# 254216  Woodblock print.History, myth and legend. Warr...
# 254217  Woodblock print. Uki-e. Combining scenes from ...
# 254218  Woodblock print. Deer and pine tree, advertise...
# 254219  Hand-coloured woodblock print, mounted as hang...
# 254220  Woodblock print, hand coloured, mounted as a h...
# 254221  Woodblock print mounted as a hanging scroll. T...
# 254222  Woodblock print. Kabuki. Actor Iwai Hanshiro a...
# 254223  Colour woodblock pillar print, hashira-e. Shid...
# 254224  Woodblock print.Nagasaki-e. Seascape. A Dutch ...
# 254225  Colour woodblock print, Oban. Portrait of the ...
# 254226  Woodblock print. Bijinga. Yosoi of the Matsuba...
# 254227  Colour woodblock print with powdered mica grou...
# 254228  Woodblock print.Classical literature. Love tha...
# 254229  Woodblock print. Bijinga. Hanazuma of the Hyog...
# 254230  Colour woodblock print. The kabuki actor Otani...
# 254231  Woodblock print. Kabuki. Actor Matsumoto Koshi...
# 254232  Woodblock print.Townscape. Masaki after a heav...
# 254233  Woodblock print. Carp leaping up a waterfall. ...
# 254234  Colour woodblock print, one sheet of an oban t...
# 254235  Woodblock print. Bijinga. Courtesan parading i...
# 254236  Woodblock print. Popular culture. Girl behind ...
# 254237  Woodblock print. Facsimile reproduction. The k...
# 254238  Woodblock print. Itinerant noodle vendor. Acco...
# 254239  Woodblock print. Popular culture. Lady attendi...
# 254240  Woodblock print. Straw dragon on a bamboo pole...
#
#                                             materials  dates
# 0                                             Woodcut   1912
# 1                                                 n/a    n/a
# 2                                                 n/a    n/a
# 3       Charcoal (?), with watercolour, over monotype   1899
# 4                                                 n/a    n/a
# 5                                                 n/a    n/a
# 6                                                 n/a    n/a
# 7                                                 n/a    n/a
# 8                                                 n/a    n/a
# 9                                                 n/a    n/a
# 10                                                n/a    n/a
# 11                                                n/a    n/a
# 12                                                n/a    n/a
# 13                                                n/a    n/a
# 14                                                n/a    n/a
# 15                                                n/a    n/a
# 16                                                n/a    n/a
# 17                                                n/a    n/a
# 18                                                n/a    n/a
# 19                                                n/a    n/a
# 20                                                n/a    n/a
# 21                                                n/a    n/a
# 22                                                n/a    n/a
# 23                                                n/a    n/a
# 24                                                n/a    n/a
# 25                                                n/a    n/a
# 26                                                n/a    n/a
# 27                                                n/a    n/a
# 28                                                n/a    n/a
# 29                                                n/a    n/a
# ...                                               ...    ...
# 254211                                            n/a    n/a
# 254212                                            n/a    n/a
# 254213                                            n/a    n/a
# 254214                                            n/a    n/a
# 254215                                            n/a    n/a
# 254216                                            n/a    n/a
# 254217                                            n/a    n/a
# 254218                                            n/a    n/a
# 254219                                            n/a    n/a
# 254220                                            n/a    n/a
# 254221                                            n/a    n/a
# 254222                                            n/a    n/a
# 254223                                            n/a    n/a
# 254224                                            n/a    n/a
# 254225                                            n/a    n/a
# 254226                                            n/a    n/a
# 254227                                            n/a    n/a
# 254228                                            n/a    n/a
# 254229                                            n/a    n/a
# 254230                                            n/a    n/a
# 254231                                            n/a    n/a
# 254232                                            n/a    n/a
# 254233                                            n/a    n/a
# 254234                                            n/a    n/a
# 254235                                            n/a    n/a
# 254236                                            n/a    n/a
# 254237                                            n/a    n/a
# 254238                                            n/a    n/a
# 254239                                            n/a    n/a
# 254240                                            n/a    n/a
#
# [254241 rows x 5 columns]

# %%
store.close()

# %%
df2 = pd.read_hdf('/data/captioning/bm_data_clean.h5', 'df')
df2
# Out:
#                                               print.value  \
# 0       http://collection.britishmuseum.org/id/object/...
# 1       http://collection.britishmuseum.org/id/object/...
# 2       http://collection.britishmuseum.org/id/object/...
# 3       http://collection.britishmuseum.org/id/object/...
# 4       http://collection.britishmuseum.org/id/object/...
# 5       http://collection.britishmuseum.org/id/object/...
# 6       http://collection.britishmuseum.org/id/object/...
# 7       http://collection.britishmuseum.org/id/object/...
# 8       http://collection.britishmuseum.org/id/object/...
# 9       http://collection.britishmuseum.org/id/object/...
# 10      http://collection.britishmuseum.org/id/object/...
# 11      http://collection.britishmuseum.org/id/object/...
# 12      http://collection.britishmuseum.org/id/object/...
# 13      http://collection.britishmuseum.org/id/object/...
# 14      http://collection.britishmuseum.org/id/object/...
# 15      http://collection.britishmuseum.org/id/object/...
# 16      http://collection.britishmuseum.org/id/object/...
# 17      http://collection.britishmuseum.org/id/object/...
# 18      http://collection.britishmuseum.org/id/object/...
# 19      http://collection.britishmuseum.org/id/object/...
# 20      http://collection.britishmuseum.org/id/object/...
# 21      http://collection.britishmuseum.org/id/object/...
# 22      http://collection.britishmuseum.org/id/object/...
# 23      http://collection.britishmuseum.org/id/object/...
# 24      http://collection.britishmuseum.org/id/object/...
# 25      http://collection.britishmuseum.org/id/object/...
# 26      http://collection.britishmuseum.org/id/object/...
# 27      http://collection.britishmuseum.org/id/object/...
# 28      http://collection.britishmuseum.org/id/object/...
# 29      http://collection.britishmuseum.org/id/object/...
# ...                                                   ...
# 254211  http://collection.britishmuseum.org/id/object/...
# 254212  http://collection.britishmuseum.org/id/object/...
# 254213  http://collection.britishmuseum.org/id/object/...
# 254214  http://collection.britishmuseum.org/id/object/...
# 254215  http://collection.britishmuseum.org/id/object/...
# 254216  http://collection.britishmuseum.org/id/object/...
# 254217  http://collection.britishmuseum.org/id/object/...
# 254218  http://collection.britishmuseum.org/id/object/...
# 254219  http://collection.britishmuseum.org/id/object/...
# 254220  http://collection.britishmuseum.org/id/object/...
# 254221  http://collection.britishmuseum.org/id/object/...
# 254222  http://collection.britishmuseum.org/id/object/...
# 254223  http://collection.britishmuseum.org/id/object/...
# 254224  http://collection.britishmuseum.org/id/object/...
# 254225  http://collection.britishmuseum.org/id/object/...
# 254226  http://collection.britishmuseum.org/id/object/...
# 254227  http://collection.britishmuseum.org/id/object/...
# 254228  http://collection.britishmuseum.org/id/object/...
# 254229  http://collection.britishmuseum.org/id/object/...
# 254230  http://collection.britishmuseum.org/id/object/...
# 254231  http://collection.britishmuseum.org/id/object/...
# 254232  http://collection.britishmuseum.org/id/object/...
# 254233  http://collection.britishmuseum.org/id/object/...
# 254234  http://collection.britishmuseum.org/id/object/...
# 254235  http://collection.britishmuseum.org/id/object/...
# 254236  http://collection.britishmuseum.org/id/object/...
# 254237  http://collection.britishmuseum.org/id/object/...
# 254238  http://collection.britishmuseum.org/id/object/...
# 254239  http://collection.britishmuseum.org/id/object/...
# 254240  http://collection.britishmuseum.org/id/object/...
#
#                                                 url.value  \
# 0       http://www.britishmuseum.org/collectionimages/...
# 1       http://www.britishmuseum.org/collectionimages/...
# 2       http://www.britishmuseum.org/collectionimages/...
# 3       http://www.britishmuseum.org/collectionimages/...
# 4       http://www.britishmuseum.org/collectionimages/...
# 5       http://www.britishmuseum.org/collectionimages/...
# 6       http://www.britishmuseum.org/collectionimages/...
# 7       http://www.britishmuseum.org/collectionimages/...
# 8       http://www.britishmuseum.org/collectionimages/...
# 9       http://www.britishmuseum.org/collectionimages/...
# 10      http://www.britishmuseum.org/collectionimages/...
# 11      http://www.britishmuseum.org/collectionimages/...
# 12      http://www.britishmuseum.org/collectionimages/...
# 13      http://www.britishmuseum.org/collectionimages/...
# 14      http://www.britishmuseum.org/collectionimages/...
# 15      http://www.britishmuseum.org/collectionimages/...
# 16      http://www.britishmuseum.org/collectionimages/...
# 17      http://www.britishmuseum.org/collectionimages/...
# 18      http://www.britishmuseum.org/collectionimages/...
# 19      http://www.britishmuseum.org/collectionimages/...
# 20      http://www.britishmuseum.org/collectionimages/...
# 21      http://www.britishmuseum.org/collectionimages/...
# 22      http://www.britishmuseum.org/collectionimages/...
# 23      http://www.britishmuseum.org/collectionimages/...
# 24      http://www.britishmuseum.org/collectionimages/...
# 25      http://www.britishmuseum.org/collectionimages/...
# 26      http://www.britishmuseum.org/collectionimages/...
# 27      http://www.britishmuseum.org/collectionimages/...
# 28      http://www.britishmuseum.org/collectionimages/...
# 29      http://www.britishmuseum.org/collectionimages/...
# ...                                                   ...
# 254211  http://www.britishmuseum.org/collectionimages/...
# 254212  http://www.britishmuseum.org/collectionimages/...
# 254213  http://www.britishmuseum.org/collectionimages/...
# 254214  http://www.britishmuseum.org/collectionimages/...
# 254215  http://www.britishmuseum.org/collectionimages/...
# 254216  http://www.britishmuseum.org/collectionimages/...
# 254217  http://www.britishmuseum.org/collectionimages/...
# 254218  http://www.britishmuseum.org/collectionimages/...
# 254219  http://www.britishmuseum.org/collectionimages/...
# 254220  http://www.britishmuseum.org/collectionimages/...
# 254221  http://www.britishmuseum.org/collectionimages/...
# 254222  http://www.britishmuseum.org/collectionimages/...
# 254223  http://www.britishmuseum.org/collectionimages/...
# 254224  http://www.britishmuseum.org/collectionimages/...
# 254225  http://www.britishmuseum.org/collectionimages/...
# 254226  http://www.britishmuseum.org/collectionimages/...
# 254227  http://www.britishmuseum.org/collectionimages/...
# 254228  http://www.britishmuseum.org/collectionimages/...
# 254229  http://www.britishmuseum.org/collectionimages/...
# 254230  http://www.britishmuseum.org/collectionimages/...
# 254231  http://www.britishmuseum.org/collectionimages/...
# 254232  http://www.britishmuseum.org/collectionimages/...
# 254233  http://www.britishmuseum.org/collectionimages/...
# 254234  http://www.britishmuseum.org/collectionimages/...
# 254235  http://www.britishmuseum.org/collectionimages/...
# 254236  http://www.britishmuseum.org/collectionimages/...
# 254237  http://www.britishmuseum.org/collectionimages/...
# 254238  http://www.britishmuseum.org/collectionimages/...
# 254239  http://www.britishmuseum.org/collectionimages/...
# 254240  http://www.britishmuseum.org/collectionimages/...
#
#                                                  captions  \
# 0       From the animal legend; antelope to left, anot...
# 1       Woodblock print. Giant lantern in the Kaminari...
# 2                 Woodblock print. Spring night at Ginza.
# 3       Le Mont de Neuville; street winding to right b...
# 4       Monochrome woodblock print. Subodai standing. ...
# 5       Colour woodblock print with powdered mica back...
# 6              Woodblock print. Beauty with unrolled obi?
# 7       Colour woodblock print with gold leaf and powd...
# 8       Illustrated book, orihon , 5 vols . Instructio...
# 9       Illustrated book, folding album, 2 vols. Varie...
# 10      Woodblock print. Woman reading with cat. Colours.
# 11      Woodblock print from an album of 37 sheets. Br...
# 12      Woodblock print from an album of 37 sheets. Gr...
# 13      Woodblock print from an album of 37 sheets. Eb...
# 14      Woodblock print from an album of thirty-seven ...
# 15      Woodblock print from an album of 37 sheets. Pe...
# 16      Woodblock print from an album of 37 sheets. Th...
# 17      Woodblock print from an album of thirty-seven ...
# 18      Woodblock print from an album of 37 sheets. Cr...
# 19      Woodblock print from an album of 37 sheets. Du...
# 20      Woodblock print from an album of 37 sheets. La...
# 21      Woodblock print from an album of 37 sheets. Pe...
# 22      Woodblock print from an album of 37 sheets. Mo...
# 23      Woodblock print from an album of 37 sheets. Lo...
# 24      Woodblock print from an album of 37 sheets. Le...
# 25      Woodblock print from an album of 37 sheets. Pe...
# 26      Woodblock print from an album of 37 sheets. Ev...
# 27      Woodblock print from an album of 37 sheets. Gi...
# 28      Woodblock print from an album of 37 sheets. Th...
# 29      Woodblock print from an album of 37 sheets. Th...
# ...                                                   ...
# 254211  Woodblock print. Bijinga. Woman stretching a l...
# 254212  Colour woodblock print, oban. A mother reading...
# 254213  Woodblock print. Bijinga. Girl holding a fan b...
# 254214  Woodblock print. Bijinga. Woman sitting with d...
# 254215  Woodblock print. Bijinga. Hanamurasaki of the ...
# 254216  Woodblock print.History, myth and legend. Warr...
# 254217  Woodblock print. Uki-e. Combining scenes from ...
# 254218  Woodblock print. Deer and pine tree, advertise...
# 254219  Hand-coloured woodblock print, mounted as hang...
# 254220  Woodblock print, hand coloured, mounted as a h...
# 254221  Woodblock print mounted as a hanging scroll. T...
# 254222  Woodblock print. Kabuki. Actor Iwai Hanshiro a...
# 254223  Colour woodblock pillar print, hashira-e. Shid...
# 254224  Woodblock print.Nagasaki-e. Seascape. A Dutch ...
# 254225  Colour woodblock print, Oban. Portrait of the ...
# 254226  Woodblock print. Bijinga. Yosoi of the Matsuba...
# 254227  Colour woodblock print with powdered mica grou...
# 254228  Woodblock print.Classical literature. Love tha...
# 254229  Woodblock print. Bijinga. Hanazuma of the Hyog...
# 254230  Colour woodblock print. The kabuki actor Otani...
# 254231  Woodblock print. Kabuki. Actor Matsumoto Koshi...
# 254232  Woodblock print.Townscape. Masaki after a heav...
# 254233  Woodblock print. Carp leaping up a waterfall. ...
# 254234  Colour woodblock print, one sheet of an oban t...
# 254235  Woodblock print. Bijinga. Courtesan parading i...
# 254236  Woodblock print. Popular culture. Girl behind ...
# 254237  Woodblock print. Facsimile reproduction. The k...
# 254238  Woodblock print. Itinerant noodle vendor. Acco...
# 254239  Woodblock print. Popular culture. Lady attendi...
# 254240  Woodblock print. Straw dragon on a bamboo pole...
#
#                                             materials  dates
# 0                                             Woodcut   1912
# 1                                                 n/a    n/a
# 2                                                 n/a    n/a
# 3       Charcoal (?), with watercolour, over monotype   1899
# 4                                                 n/a    n/a
# 5                                                 n/a    n/a
# 6                                                 n/a    n/a
# 7                                                 n/a    n/a
# 8                                                 n/a    n/a
# 9                                                 n/a    n/a
# 10                                                n/a    n/a
# 11                                                n/a    n/a
# 12                                                n/a    n/a
# 13                                                n/a    n/a
# 14                                                n/a    n/a
# 15                                                n/a    n/a
# 16                                                n/a    n/a
# 17                                                n/a    n/a
# 18                                                n/a    n/a
# 19                                                n/a    n/a
# 20                                                n/a    n/a
# 21                                                n/a    n/a
# 22                                                n/a    n/a
# 23                                                n/a    n/a
# 24                                                n/a    n/a
# 25                                                n/a    n/a
# 26                                                n/a    n/a
# 27                                                n/a    n/a
# 28                                                n/a    n/a
# 29                                                n/a    n/a
# ...                                               ...    ...
# 254211                                            n/a    n/a
# 254212                                            n/a    n/a
# 254213                                            n/a    n/a
# 254214                                            n/a    n/a
# 254215                                            n/a    n/a
# 254216                                            n/a    n/a
# 254217                                            n/a    n/a
# 254218                                            n/a    n/a
# 254219                                            n/a    n/a
# 254220                                            n/a    n/a
# 254221                                            n/a    n/a
# 254222                                            n/a    n/a
# 254223                                            n/a    n/a
# 254224                                            n/a    n/a
# 254225                                            n/a    n/a
# 254226                                            n/a    n/a
# 254227                                            n/a    n/a
# 254228                                            n/a    n/a
# 254229                                            n/a    n/a
# 254230                                            n/a    n/a
# 254231                                            n/a    n/a
# 254232                                            n/a    n/a
# 254233                                            n/a    n/a
# 254234                                            n/a    n/a
# 254235                                            n/a    n/a
# 254236                                            n/a    n/a
# 254237                                            n/a    n/a
# 254238                                            n/a    n/a
# 254239                                            n/a    n/a
# 254240                                            n/a    n/a
#
# [254241 rows x 5 columns]

# %%
list(df2.sample(100)['url.value'])
# Out:
# [u'http://www.britishmuseum.org/collectionimages/AN00862/AN00862742_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00082/AN00082427_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00976/AN00976435_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00086/AN00086856_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00342/AN00342448_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00118/AN00118567_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01016/AN01016233_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00156/AN00156783_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00980/AN00980032_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01022/AN01022508_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00572/AN00572858_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00062/AN00062217_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00059/AN00059252_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00435/AN00435608_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00876/AN00876348_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00522/AN00522639_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00530/AN00530209_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00479/AN00479447_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00474/AN00474056_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01048/AN01048315_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00122/AN00122930_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00602/AN00602854_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00453/AN00453761_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00110/AN00110822_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01154/AN01154028_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00118/AN00118704_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01155/AN01155311_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00695/AN00695663_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00480/AN00480564_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00963/AN00963141_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01359/AN01359474_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00800/AN00800585_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00303/AN00303674_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00329/AN00329606_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00555/AN00555809_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01153/AN01153789_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00048/AN00048423_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01154/AN01154998_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01109/AN01109573_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01080/AN01080310_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00816/AN00816458_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00073/AN00073204_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01156/AN01156159_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00466/AN00466477_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00022/AN00022195_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00508/AN00508649_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00474/AN00474235_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00847/AN00847400_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00099/AN00099143_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01043/AN01043464_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00955/AN00955551_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00460/AN00460299_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00704/AN00704327_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00803/AN00803429_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00183/AN00183687_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00091/AN00091979_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00554/AN00554894_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00580/AN00580368_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01013/AN01013441_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00980/AN00980641_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00521/AN00521251_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00830/AN00830638_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01366/AN01366234_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01317/AN01317609_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00822/AN00822447_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01182/AN01182394_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00103/AN00103926_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01162/AN01162720_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00219/AN00219220_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00101/AN00101371_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00106/AN00106783_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00823/AN00823475_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01314/AN01314490_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00521/AN00521659_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01033/AN01033843_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00575/AN00575043_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01247/AN01247289_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00071/AN00071888_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00835/AN00835456_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00128/AN00128291_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00703/AN00703218_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00375/AN00375955_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00649/AN00649764_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00064/AN00064702_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01320/AN01320113_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01194/AN01194360_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00067/AN00067866_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00978/AN00978912_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01291/AN01291641_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01302/AN01302849_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00239/AN00239091_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01049/AN01049583_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00519/AN00519667_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00059/AN00059428_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00977/AN00977326_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01343/AN01343333_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN01084/AN01084758_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00768/AN00768154_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00891/AN00891841_001_l.jpg',
#  u'http://www.britishmuseum.org/collectionimages/AN00514/AN00514710_001_l.jpg']
