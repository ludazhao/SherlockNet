# %%
import os.path
import re
import sys
import numpy as np
import json
import time
from six.moves import urllib
import matplotlib as mpl
from pprint import pprint
import pandas as pd

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
#Load the data
data = None

with open('/data/captioning/bm_prints_urls_captions.json') as f:
    data = json.load(f)

# %%
img_arr = data['results']['bindings']
len(img_arr)
# Out:
# 782550

# %%
pprint(img_arr[0:20])
# Out:
# [{u'caption': {u'type': u'literal',
#                u'value': u'From the animal legend; antelope to left, another(?) lying centre. 1912\nWoodcut'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/PPA8330'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00107/AN00107870_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'From the animal legend; antelope to left, another(?) lying centre. 1912\nWoodcut'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/P_1982-0724-21'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00107/AN00107870_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'From the animal legend; antelope to left, another(?) lying centre. 1912\nWoodcut'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/1045'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00107/AN00107870_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Woodblock print. Giant lantern in the Kaminari-mon of Senso-ji temple.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/JCF11708'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00489/AN00489936_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Woodblock print. Giant lantern in the Kaminari-mon of Senso-ji temple.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/J_1981-0225-0-4-a'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00489/AN00489936_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Woodblock print. Giant lantern in the Kaminari-mon of Senso-ji temple.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/1405'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00489/AN00489936_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Woodblock print. Spring night at Ginza.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/JCF11709'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00244/AN00244222_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Woodblock print. Spring night at Ginza.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/J_1981-0225-0-4-b'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00244/AN00244222_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Woodblock print. Spring night at Ginza.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/1406'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00244/AN00244222_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Le Mont de Neuville; street winding to right beyond, flanked by buildings on both sides, at right figure in doorway and beyond figure standing in middle of road. 1899\nCharcoal (?), with watercolour, over monotype'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/PDB17329'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00266/AN00266509_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Le Mont de Neuville; street winding to right beyond, flanked by buildings on both sides, at right figure in doorway and beyond figure standing in middle of road. 1899\nCharcoal (?), with watercolour, over monotype'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/P_1981-0328-5'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00266/AN00266509_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Le Mont de Neuville; street winding to right beyond, flanked by buildings on both sides, at right figure in doorway and beyond figure standing in middle of road. 1899\nCharcoal (?), with watercolour, over monotype'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/1551'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00266/AN00266509_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Monochrome woodblock print. Subodai standing. Signed, sealed, inscribed and marked.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/JCF11731'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00225/AN00225242_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Monochrome woodblock print. Subodai standing. Signed, sealed, inscribed and marked.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/J_1981-0331-0-2'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00225/AN00225242_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Monochrome woodblock print. Subodai standing. Signed, sealed, inscribed and marked.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/1563'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00225/AN00225242_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Colour woodblock print with powdered mica background. Woman in loose kimono sitting on cushion in front of mirror. Signed, dated and sealed.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/JCF11738'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00224/AN00224520_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Colour woodblock print with powdered mica background. Woman in loose kimono sitting on cushion in front of mirror. Signed, dated and sealed.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/J_1981-0410-0-2'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00224/AN00224520_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Colour woodblock print with powdered mica background. Woman in loose kimono sitting on cushion in front of mirror. Signed, dated and sealed.'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/1621'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00224/AN00224520_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Woodblock print. Beauty with unrolled obi?'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/JCF11739'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00244/AN00244199_001_l.jpg'}},
#  {u'caption': {u'type': u'literal',
#                u'value': u'Woodblock print. Beauty with unrolled obi?'},
#   u'print': {u'type': u'uri',
#              u'value': u'http://collection.britishmuseum.org/id/object/J_1981-0410-0-3'},
#   u'url': {u'type': u'uri',
#            u'value': u'http://www.britishmuseum.org/collectionimages/AN00244/AN00244199_001_l.jpg'}}]

# %%
start = time.time()

# Filter by unqiue uris
from pandas.io.json import json_normalize

df = json_normalize(img_arr)
df.drop('caption.type', axis=1, inplace=True)
df.drop('print.type', axis=1, inplace=True)
df.drop('url.type', axis=1, inplace=True)
df.head()

print "Time:" + str(time.time() - start)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-cf322a42f140> in <module>()
#       4 from pandas.io.json import json_normalize
#       5
# ----> 6 df = json_normalize(img_arr)
#       7 df.drop('caption.type', axis=1, inplace=True)
#       8 df.drop('print.type', axis=1, inplace=True)
#
# /Library/Python/2.7/site-packages/pandas/io/json.pyc in json_normalize(data, record_path, meta, meta_prefix, record_prefix)
#     713             # TODO: handle record value which are lists, at least error
#     714             #       reasonably
# --> 715             data = nested_to_record(data)
#     716         return DataFrame(data)
#     717     elif not isinstance(record_path, list):
#
# /Library/Python/2.7/site-packages/pandas/io/json.pyc in nested_to_record(ds, prefix, level)
#     628             else:
#     629                 v = new_d.pop(k)
# --> 630                 new_d.update(nested_to_record(v, newkey, level+1))
#     631         new_ds.append(new_d)
#     632
#
# /Library/Python/2.7/site-packages/pandas/io/json.pyc in nested_to_record(ds, prefix, level)
#     611     for d in ds:
#     612
# --> 613         new_d = copy.deepcopy(d)
#     614         for k, v in d.items():
#     615             # each key gets renamed with prefix
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/copy.pyc in deepcopy(x, memo, _nil)
#     190                 y = _reconstruct(x, rv, 1, memo)
#     191
# --> 192     memo[d] = y
#     193     _keep_alive(x, memo) # Make sure x lives at least as long as d
#     194     return y
#
# KeyboardInterrupt:

# %%
df.head()
# Out:
#                                        caption.value  \
# 0  From the animal legend; antelope to left, anot...
# 1  From the animal legend; antelope to left, anot...
# 2  From the animal legend; antelope to left, anot...
# 3  Woodblock print. Giant lantern in the Kaminari...
# 4  Woodblock print. Giant lantern in the Kaminari...
#
#                                          print.value  \
# 0  http://collection.britishmuseum.org/id/object/...
# 1  http://collection.britishmuseum.org/id/object/...
# 2  http://collection.britishmuseum.org/id/object/...
# 3  http://collection.britishmuseum.org/id/object/...
# 4  http://collection.britishmuseum.org/id/object/...
#
#                                            url.value
# 0  http://www.britishmuseum.org/collectionimages/...
# 1  http://www.britishmuseum.org/collectionimages/...
# 2  http://www.britishmuseum.org/collectionimages/...
# 3  http://www.britishmuseum.org/collectionimages/...
# 4  http://www.britishmuseum.org/collectionimages/...

# %%
# Drop duplicates according to caption.value and url.value
start = time.time()

print len(df)
df.drop_duplicates(subset=['caption.value', 'url.value'], inplace=True)
print len(df)

print "Time:" + str(time.time() - start)
# Out:
# 782550
# 258103
# Time:8.21036314964

# %%
df_count = df.groupby(['url.value']).size().reset_index().rename(columns={0:'count'})

# %%
# look if some objects have more than 1 captions
df_count['count'].value_counts()
# Out:
# 1    253884
# 2      2072
# 3        11
# 4         6
# 6         3
# Name: count, dtype: int64

# %%
#Drop further dup urls
df.drop_duplicates(subset=['url.value'], inplace=True)
print len(df)
# Out:
# 255976

# %%
# get shortering data to work with
df_tiny = df[:5].copy()

# %%
df_tiny['capt_length'] = df_tiny['caption.value'].map(lambda x: len(x.split()))
df_tiny
# Out:
#                                         caption.value  \
# 0   From the animal legend; antelope to left, anot...
# 3   Woodblock print. Giant lantern in the Kaminari...
# 6             Woodblock print. Spring night at Ginza.
# 9   Le Mont de Neuville; street winding to right b...
# 12  Monochrome woodblock print. Subodai standing. ...
#
#                                           print.value  \
# 0   http://collection.britishmuseum.org/id/object/...
# 3   http://collection.britishmuseum.org/id/object/...
# 6   http://collection.britishmuseum.org/id/object/...
# 9   http://collection.britishmuseum.org/id/object/...
# 12  http://collection.britishmuseum.org/id/object/...
#
#                                             url.value  capt_length
# 0   http://www.britishmuseum.org/collectionimages/...           12
# 3   http://www.britishmuseum.org/collectionimages/...           10
# 6   http://www.britishmuseum.org/collectionimages/...            6
# 9   http://www.britishmuseum.org/collectionimages/...           35
# 12  http://www.britishmuseum.org/collectionimages/...           10

# %%
## Add caption length
df['capt_length'] = df['caption.value'].map(lambda x: len(x.split()))
df.tail(5)
# Out:
#                                             caption.value  \
# 782535  Woodblock print. Popular culture. Girl behind ...
# 782538  Woodblock print. Facsimile reproduction. The k...
# 782541  Woodblock print. Itinerant noodle vendor. Acco...
# 782544  Woodblock print. Popular culture. Lady attendi...
# 782547  Woodblock print. Straw dragon on a bamboo pole...
#
#                                               print.value  \
# 782535  http://collection.britishmuseum.org/id/object/...
# 782538  http://collection.britishmuseum.org/id/object/...
# 782541  http://collection.britishmuseum.org/id/object/...
# 782544  http://collection.britishmuseum.org/id/object/...
# 782547  http://collection.britishmuseum.org/id/object/...
#
#                                                 url.value  capt_length
# 782535  http://www.britishmuseum.org/collectionimages/...           35
# 782538  http://www.britishmuseum.org/collectionimages/...           32
# 782541  http://www.britishmuseum.org/collectionimages/...            9
# 782544  http://www.britishmuseum.org/collectionimages/...           10
# 782547  http://www.britishmuseum.org/collectionimages/...           17

# %%
#reset index 
df.reset_index(drop=True)
# Out:
#                                             caption.value  \
# 0       From the animal legend; antelope to left, anot...
# 1       Woodblock print. Giant lantern in the Kaminari...
# 2                 Woodblock print. Spring night at Ginza.
# 3       Le Mont de Neuville; street winding to right b...
# 4       Monochrome woodblock print. Subodai standing. ...
# 5       Colour woodblock print with powdered mica back...
# 6              Woodblock print. Beauty with unrolled obi?
# 7       Colour woodblock print with gold leaf and powd...
# 8       Illustrated book, orihon (folding album), 5 vo...
# 9       Illustrated book, folding album, 2 vols. Varie...
# 10                                       Woodblock print.
# 11      Woodblock print. Woman reading with cat. Colours.
# 12      Woodblock print from an album of 37 sheets. Br...
# 13      Woodblock print from an album of 37 sheets. Gr...
# 14      Woodblock print from an album of 37 sheets. Eb...
# 15      Woodblock print from an album of thirty-seven ...
# 16      Woodblock print from an album of 37 sheets. Pe...
# 17      Woodblock print from an album of 37 sheets. Th...
# 18      Woodblock print from an album of thirty-seven ...
# 19      Woodblock print from an album of 37 sheets. Cr...
# 20      Woodblock print from an album of 37 sheets. Du...
# 21      Woodblock print from an album of 37 sheets. La...
# 22      Woodblock print from an album of 37 sheets. Pe...
# 23      Woodblock print from an album of 37 sheets. Mo...
# 24      Woodblock print from an album of 37 sheets. Lo...
# 25      Woodblock print from an album of 37 sheets. Le...
# 26      Woodblock print from an album of 37 sheets. Pe...
# 27      Woodblock print from an album of 37 sheets. Ev...
# 28      Woodblock print from an album of 37 sheets. Gi...
# 29      Woodblock print from an album of 37 sheets. Th...
# ...                                                   ...
# 255946  Woodblock print. Bijinga. Woman stretching a l...
# 255947  Colour woodblock print, oban. A mother reading...
# 255948  Woodblock print. Bijinga. Girl holding a fan b...
# 255949  Woodblock print. Bijinga. Woman sitting with d...
# 255950  Woodblock print. Bijinga. Hanamurasaki of the ...
# 255951  Woodblock print.History, myth and legend. Warr...
# 255952  Woodblock print. Uki-e. Combining scenes from ...
# 255953  Woodblock print. Deer and pine tree, advertise...
# 255954  Hand-coloured woodblock print, mounted as hang...
# 255955  Woodblock print, hand coloured, mounted as a h...
# 255956  Woodblock print mounted as a hanging scroll. T...
# 255957  Woodblock print. Kabuki. Actor Iwai Hanshiro a...
# 255958  Colour woodblock pillar print, hashira-e. Shid...
# 255959  Woodblock print.Nagasaki-e. Seascape. A Dutch ...
# 255960  Colour woodblock print, Oban. Portrait of the ...
# 255961  Woodblock print. Bijinga. Yosoi of the Matsuba...
# 255962  Colour woodblock print with powdered mica grou...
# 255963  Woodblock print.Classical literature. Love tha...
# 255964  Woodblock print. Bijinga. Hanazuma of the Hyog...
# 255965  Colour woodblock print. The kabuki actor Otani...
# 255966  Woodblock print. Kabuki. Actor Matsumoto Koshi...
# 255967  Woodblock print.Townscape. Masaki after a heav...
# 255968  Woodblock print. Carp leaping up a waterfall. ...
# 255969  Colour woodblock print, one sheet of an oban t...
# 255970  Woodblock print. Bijinga. Courtesan parading i...
# 255971  Woodblock print. Popular culture. Girl behind ...
# 255972  Woodblock print. Facsimile reproduction. The k...
# 255973  Woodblock print. Itinerant noodle vendor. Acco...
# 255974  Woodblock print. Popular culture. Lady attendi...
# 255975  Woodblock print. Straw dragon on a bamboo pole...
#
#                                               print.value  \
# 0       http://collection.britishmuseum.org/id/object/...
# 1       http://collection.britishmuseum.org/id/object/...
# 2       http://collection.britishmuseum.org/id/object/...
# 3       http://collection.britishmuseum.org/id/object/...
# 4       http://collection.britishmuseum.org/id/object/...
# 5       http://collection.britishmuseum.org/id/object/...
# 6       http://collection.britishmuseum.org/id/object/...
# 7       http://collection.britishmuseum.org/id/object/...
# 8       http://collection.britishmuseum.org/id/object/...
# 9       http://collection.britishmuseum.org/id/object/...
# 10      http://collection.britishmuseum.org/id/object/...
# 11      http://collection.britishmuseum.org/id/object/...
# 12      http://collection.britishmuseum.org/id/object/...
# 13      http://collection.britishmuseum.org/id/object/...
# 14      http://collection.britishmuseum.org/id/object/...
# 15      http://collection.britishmuseum.org/id/object/...
# 16      http://collection.britishmuseum.org/id/object/...
# 17      http://collection.britishmuseum.org/id/object/...
# 18      http://collection.britishmuseum.org/id/object/...
# 19      http://collection.britishmuseum.org/id/object/...
# 20      http://collection.britishmuseum.org/id/object/...
# 21      http://collection.britishmuseum.org/id/object/...
# 22      http://collection.britishmuseum.org/id/object/...
# 23      http://collection.britishmuseum.org/id/object/...
# 24      http://collection.britishmuseum.org/id/object/...
# 25      http://collection.britishmuseum.org/id/object/...
# 26      http://collection.britishmuseum.org/id/object/...
# 27      http://collection.britishmuseum.org/id/object/...
# 28      http://collection.britishmuseum.org/id/object/...
# 29      http://collection.britishmuseum.org/id/object/...
# ...                                                   ...
# 255946  http://collection.britishmuseum.org/id/object/...
# 255947  http://collection.britishmuseum.org/id/object/...
# 255948  http://collection.britishmuseum.org/id/object/...
# 255949  http://collection.britishmuseum.org/id/object/...
# 255950  http://collection.britishmuseum.org/id/object/...
# 255951  http://collection.britishmuseum.org/id/object/...
# 255952  http://collection.britishmuseum.org/id/object/...
# 255953  http://collection.britishmuseum.org/id/object/...
# 255954  http://collection.britishmuseum.org/id/object/...
# 255955  http://collection.britishmuseum.org/id/object/...
# 255956  http://collection.britishmuseum.org/id/object/...
# 255957  http://collection.britishmuseum.org/id/object/...
# 255958  http://collection.britishmuseum.org/id/object/...
# 255959  http://collection.britishmuseum.org/id/object/...
# 255960  http://collection.britishmuseum.org/id/object/...
# 255961  http://collection.britishmuseum.org/id/object/...
# 255962  http://collection.britishmuseum.org/id/object/...
# 255963  http://collection.britishmuseum.org/id/object/...
# 255964  http://collection.britishmuseum.org/id/object/...
# 255965  http://collection.britishmuseum.org/id/object/...
# 255966  http://collection.britishmuseum.org/id/object/...
# 255967  http://collection.britishmuseum.org/id/object/...
# 255968  http://collection.britishmuseum.org/id/object/...
# 255969  http://collection.britishmuseum.org/id/object/...
# 255970  http://collection.britishmuseum.org/id/object/...
# 255971  http://collection.britishmuseum.org/id/object/...
# 255972  http://collection.britishmuseum.org/id/object/...
# 255973  http://collection.britishmuseum.org/id/object/...
# 255974  http://collection.britishmuseum.org/id/object/...
# 255975  http://collection.britishmuseum.org/id/object/...
#
#                                                 url.value  capt_length
# 0       http://www.britishmuseum.org/collectionimages/...           12
# 1       http://www.britishmuseum.org/collectionimages/...           10
# 2       http://www.britishmuseum.org/collectionimages/...            6
# 3       http://www.britishmuseum.org/collectionimages/...           35
# 4       http://www.britishmuseum.org/collectionimages/...           10
# 5       http://www.britishmuseum.org/collectionimages/...           22
# 6       http://www.britishmuseum.org/collectionimages/...            6
# 7       http://www.britishmuseum.org/collectionimages/...           24
# 8       http://www.britishmuseum.org/collectionimages/...           31
# 9       http://www.britishmuseum.org/collectionimages/...           11
# 10      http://www.britishmuseum.org/collectionimages/...            2
# 11      http://www.britishmuseum.org/collectionimages/...            7
# 12      http://www.britishmuseum.org/collectionimages/...           18
# 13      http://www.britishmuseum.org/collectionimages/...           16
# 14      http://www.britishmuseum.org/collectionimages/...           22
# 15      http://www.britishmuseum.org/collectionimages/...           13
# 16      http://www.britishmuseum.org/collectionimages/...           18
# 17      http://www.britishmuseum.org/collectionimages/...           18
# 18      http://www.britishmuseum.org/collectionimages/...           21
# 19      http://www.britishmuseum.org/collectionimages/...           15
# 20      http://www.britishmuseum.org/collectionimages/...           16
# 21      http://www.britishmuseum.org/collectionimages/...           15
# 22      http://www.britishmuseum.org/collectionimages/...           18
# 23      http://www.britishmuseum.org/collectionimages/...           24
# 24      http://www.britishmuseum.org/collectionimages/...           18
# 25      http://www.britishmuseum.org/collectionimages/...           19
# 26      http://www.britishmuseum.org/collectionimages/...           19
# 27      http://www.britishmuseum.org/collectionimages/...           20
# 28      http://www.britishmuseum.org/collectionimages/...           19
# 29      http://www.britishmuseum.org/collectionimages/...           18
# ...                                                   ...          ...
# 255946  http://www.britishmuseum.org/collectionimages/...           12
# 255947  http://www.britishmuseum.org/collectionimages/...           27
# 255948  http://www.britishmuseum.org/collectionimages/...           19
# 255949  http://www.britishmuseum.org/collectionimages/...           10
# 255950  http://www.britishmuseum.org/collectionimages/...           15
# 255951  http://www.britishmuseum.org/collectionimages/...           20
# 255952  http://www.britishmuseum.org/collectionimages/...           27
# 255953  http://www.britishmuseum.org/collectionimages/...           12
# 255954  http://www.britishmuseum.org/collectionimages/...           14
# 255955  http://www.britishmuseum.org/collectionimages/...           26
# 255956  http://www.britishmuseum.org/collectionimages/...           13
# 255957  http://www.britishmuseum.org/collectionimages/...           16
# 255958  http://www.britishmuseum.org/collectionimages/...           27
# 255959  http://www.britishmuseum.org/collectionimages/...           30
# 255960  http://www.britishmuseum.org/collectionimages/...           50
# 255961  http://www.britishmuseum.org/collectionimages/...            9
# 255962  http://www.britishmuseum.org/collectionimages/...           26
# 255963  http://www.britishmuseum.org/collectionimages/...           35
# 255964  http://www.britishmuseum.org/collectionimages/...           23
# 255965  http://www.britishmuseum.org/collectionimages/...           14
# 255966  http://www.britishmuseum.org/collectionimages/...           25
# 255967  http://www.britishmuseum.org/collectionimages/...           21
# 255968  http://www.britishmuseum.org/collectionimages/...           10
# 255969  http://www.britishmuseum.org/collectionimages/...           54
# 255970  http://www.britishmuseum.org/collectionimages/...           22
# 255971  http://www.britishmuseum.org/collectionimages/...           35
# 255972  http://www.britishmuseum.org/collectionimages/...           32
# 255973  http://www.britishmuseum.org/collectionimages/...            9
# 255974  http://www.britishmuseum.org/collectionimages/...           10
# 255975  http://www.britishmuseum.org/collectionimages/...           17
#
# [255976 rows x 4 columns]

# %%
#plot occurrences of each length

from collections import Counter
c = Counter(df['capt_length'])
plt.plot(*zip(*sorted(c.items())))
plt.xlim(1,10)
# Out:
# (1, 10)

# %%
#There's roughly around 1k of words less than 5. Remove them.
df = df[df['capt_length'] > 5]
df.reset_index(drop=True)
# Out:
#                                             caption.value  \
# 0       From the animal legend; antelope to left, anot...
# 1       Woodblock print. Giant lantern in the Kaminari...
# 2                 Woodblock print. Spring night at Ginza.
# 3       Le Mont de Neuville; street winding to right b...
# 4       Monochrome woodblock print. Subodai standing. ...
# 5       Colour woodblock print with powdered mica back...
# 6              Woodblock print. Beauty with unrolled obi?
# 7       Colour woodblock print with gold leaf and powd...
# 8       Illustrated book, orihon (folding album), 5 vo...
# 9       Illustrated book, folding album, 2 vols. Varie...
# 10      Woodblock print. Woman reading with cat. Colours.
# 11      Woodblock print from an album of 37 sheets. Br...
# 12      Woodblock print from an album of 37 sheets. Gr...
# 13      Woodblock print from an album of 37 sheets. Eb...
# 14      Woodblock print from an album of thirty-seven ...
# 15      Woodblock print from an album of 37 sheets. Pe...
# 16      Woodblock print from an album of 37 sheets. Th...
# 17      Woodblock print from an album of thirty-seven ...
# 18      Woodblock print from an album of 37 sheets. Cr...
# 19      Woodblock print from an album of 37 sheets. Du...
# 20      Woodblock print from an album of 37 sheets. La...
# 21      Woodblock print from an album of 37 sheets. Pe...
# 22      Woodblock print from an album of 37 sheets. Mo...
# 23      Woodblock print from an album of 37 sheets. Lo...
# 24      Woodblock print from an album of 37 sheets. Le...
# 25      Woodblock print from an album of 37 sheets. Pe...
# 26      Woodblock print from an album of 37 sheets. Ev...
# 27      Woodblock print from an album of 37 sheets. Gi...
# 28      Woodblock print from an album of 37 sheets. Th...
# 29      Woodblock print from an album of 37 sheets. Th...
# ...                                                   ...
# 254211  Woodblock print. Bijinga. Woman stretching a l...
# 254212  Colour woodblock print, oban. A mother reading...
# 254213  Woodblock print. Bijinga. Girl holding a fan b...
# 254214  Woodblock print. Bijinga. Woman sitting with d...
# 254215  Woodblock print. Bijinga. Hanamurasaki of the ...
# 254216  Woodblock print.History, myth and legend. Warr...
# 254217  Woodblock print. Uki-e. Combining scenes from ...
# 254218  Woodblock print. Deer and pine tree, advertise...
# 254219  Hand-coloured woodblock print, mounted as hang...
# 254220  Woodblock print, hand coloured, mounted as a h...
# 254221  Woodblock print mounted as a hanging scroll. T...
# 254222  Woodblock print. Kabuki. Actor Iwai Hanshiro a...
# 254223  Colour woodblock pillar print, hashira-e. Shid...
# 254224  Woodblock print.Nagasaki-e. Seascape. A Dutch ...
# 254225  Colour woodblock print, Oban. Portrait of the ...
# 254226  Woodblock print. Bijinga. Yosoi of the Matsuba...
# 254227  Colour woodblock print with powdered mica grou...
# 254228  Woodblock print.Classical literature. Love tha...
# 254229  Woodblock print. Bijinga. Hanazuma of the Hyog...
# 254230  Colour woodblock print. The kabuki actor Otani...
# 254231  Woodblock print. Kabuki. Actor Matsumoto Koshi...
# 254232  Woodblock print.Townscape. Masaki after a heav...
# 254233  Woodblock print. Carp leaping up a waterfall. ...
# 254234  Colour woodblock print, one sheet of an oban t...
# 254235  Woodblock print. Bijinga. Courtesan parading i...
# 254236  Woodblock print. Popular culture. Girl behind ...
# 254237  Woodblock print. Facsimile reproduction. The k...
# 254238  Woodblock print. Itinerant noodle vendor. Acco...
# 254239  Woodblock print. Popular culture. Lady attendi...
# 254240  Woodblock print. Straw dragon on a bamboo pole...
#
#                                               print.value  \
# 0       http://collection.britishmuseum.org/id/object/...
# 1       http://collection.britishmuseum.org/id/object/...
# 2       http://collection.britishmuseum.org/id/object/...
# 3       http://collection.britishmuseum.org/id/object/...
# 4       http://collection.britishmuseum.org/id/object/...
# 5       http://collection.britishmuseum.org/id/object/...
# 6       http://collection.britishmuseum.org/id/object/...
# 7       http://collection.britishmuseum.org/id/object/...
# 8       http://collection.britishmuseum.org/id/object/...
# 9       http://collection.britishmuseum.org/id/object/...
# 10      http://collection.britishmuseum.org/id/object/...
# 11      http://collection.britishmuseum.org/id/object/...
# 12      http://collection.britishmuseum.org/id/object/...
# 13      http://collection.britishmuseum.org/id/object/...
# 14      http://collection.britishmuseum.org/id/object/...
# 15      http://collection.britishmuseum.org/id/object/...
# 16      http://collection.britishmuseum.org/id/object/...
# 17      http://collection.britishmuseum.org/id/object/...
# 18      http://collection.britishmuseum.org/id/object/...
# 19      http://collection.britishmuseum.org/id/object/...
# 20      http://collection.britishmuseum.org/id/object/...
# 21      http://collection.britishmuseum.org/id/object/...
# 22      http://collection.britishmuseum.org/id/object/...
# 23      http://collection.britishmuseum.org/id/object/...
# 24      http://collection.britishmuseum.org/id/object/...
# 25      http://collection.britishmuseum.org/id/object/...
# 26      http://collection.britishmuseum.org/id/object/...
# 27      http://collection.britishmuseum.org/id/object/...
# 28      http://collection.britishmuseum.org/id/object/...
# 29      http://collection.britishmuseum.org/id/object/...
# ...                                                   ...
# 254211  http://collection.britishmuseum.org/id/object/...
# 254212  http://collection.britishmuseum.org/id/object/...
# 254213  http://collection.britishmuseum.org/id/object/...
# 254214  http://collection.britishmuseum.org/id/object/...
# 254215  http://collection.britishmuseum.org/id/object/...
# 254216  http://collection.britishmuseum.org/id/object/...
# 254217  http://collection.britishmuseum.org/id/object/...
# 254218  http://collection.britishmuseum.org/id/object/...
# 254219  http://collection.britishmuseum.org/id/object/...
# 254220  http://collection.britishmuseum.org/id/object/...
# 254221  http://collection.britishmuseum.org/id/object/...
# 254222  http://collection.britishmuseum.org/id/object/...
# 254223  http://collection.britishmuseum.org/id/object/...
# 254224  http://collection.britishmuseum.org/id/object/...
# 254225  http://collection.britishmuseum.org/id/object/...
# 254226  http://collection.britishmuseum.org/id/object/...
# 254227  http://collection.britishmuseum.org/id/object/...
# 254228  http://collection.britishmuseum.org/id/object/...
# 254229  http://collection.britishmuseum.org/id/object/...
# 254230  http://collection.britishmuseum.org/id/object/...
# 254231  http://collection.britishmuseum.org/id/object/...
# 254232  http://collection.britishmuseum.org/id/object/...
# 254233  http://collection.britishmuseum.org/id/object/...
# 254234  http://collection.britishmuseum.org/id/object/...
# 254235  http://collection.britishmuseum.org/id/object/...
# 254236  http://collection.britishmuseum.org/id/object/...
# 254237  http://collection.britishmuseum.org/id/object/...
# 254238  http://collection.britishmuseum.org/id/object/...
# 254239  http://collection.britishmuseum.org/id/object/...
# 254240  http://collection.britishmuseum.org/id/object/...
#
#                                                 url.value  capt_length
# 0       http://www.britishmuseum.org/collectionimages/...           12
# 1       http://www.britishmuseum.org/collectionimages/...           10
# 2       http://www.britishmuseum.org/collectionimages/...            6
# 3       http://www.britishmuseum.org/collectionimages/...           35
# 4       http://www.britishmuseum.org/collectionimages/...           10
# 5       http://www.britishmuseum.org/collectionimages/...           22
# 6       http://www.britishmuseum.org/collectionimages/...            6
# 7       http://www.britishmuseum.org/collectionimages/...           24
# 8       http://www.britishmuseum.org/collectionimages/...           31
# 9       http://www.britishmuseum.org/collectionimages/...           11
# 10      http://www.britishmuseum.org/collectionimages/...            7
# 11      http://www.britishmuseum.org/collectionimages/...           18
# 12      http://www.britishmuseum.org/collectionimages/...           16
# 13      http://www.britishmuseum.org/collectionimages/...           22
# 14      http://www.britishmuseum.org/collectionimages/...           13
# 15      http://www.britishmuseum.org/collectionimages/...           18
# 16      http://www.britishmuseum.org/collectionimages/...           18
# 17      http://www.britishmuseum.org/collectionimages/...           21
# 18      http://www.britishmuseum.org/collectionimages/...           15
# 19      http://www.britishmuseum.org/collectionimages/...           16
# 20      http://www.britishmuseum.org/collectionimages/...           15
# 21      http://www.britishmuseum.org/collectionimages/...           18
# 22      http://www.britishmuseum.org/collectionimages/...           24
# 23      http://www.britishmuseum.org/collectionimages/...           18
# 24      http://www.britishmuseum.org/collectionimages/...           19
# 25      http://www.britishmuseum.org/collectionimages/...           19
# 26      http://www.britishmuseum.org/collectionimages/...           20
# 27      http://www.britishmuseum.org/collectionimages/...           19
# 28      http://www.britishmuseum.org/collectionimages/...           18
# 29      http://www.britishmuseum.org/collectionimages/...           18
# ...                                                   ...          ...
# 254211  http://www.britishmuseum.org/collectionimages/...           12
# 254212  http://www.britishmuseum.org/collectionimages/...           27
# 254213  http://www.britishmuseum.org/collectionimages/...           19
# 254214  http://www.britishmuseum.org/collectionimages/...           10
# 254215  http://www.britishmuseum.org/collectionimages/...           15
# 254216  http://www.britishmuseum.org/collectionimages/...           20
# 254217  http://www.britishmuseum.org/collectionimages/...           27
# 254218  http://www.britishmuseum.org/collectionimages/...           12
# 254219  http://www.britishmuseum.org/collectionimages/...           14
# 254220  http://www.britishmuseum.org/collectionimages/...           26
# 254221  http://www.britishmuseum.org/collectionimages/...           13
# 254222  http://www.britishmuseum.org/collectionimages/...           16
# 254223  http://www.britishmuseum.org/collectionimages/...           27
# 254224  http://www.britishmuseum.org/collectionimages/...           30
# 254225  http://www.britishmuseum.org/collectionimages/...           50
# 254226  http://www.britishmuseum.org/collectionimages/...            9
# 254227  http://www.britishmuseum.org/collectionimages/...           26
# 254228  http://www.britishmuseum.org/collectionimages/...           35
# 254229  http://www.britishmuseum.org/collectionimages/...           23
# 254230  http://www.britishmuseum.org/collectionimages/...           14
# 254231  http://www.britishmuseum.org/collectionimages/...           25
# 254232  http://www.britishmuseum.org/collectionimages/...           21
# 254233  http://www.britishmuseum.org/collectionimages/...           10
# 254234  http://www.britishmuseum.org/collectionimages/...           54
# 254235  http://www.britishmuseum.org/collectionimages/...           22
# 254236  http://www.britishmuseum.org/collectionimages/...           35
# 254237  http://www.britishmuseum.org/collectionimages/...           32
# 254238  http://www.britishmuseum.org/collectionimages/...            9
# 254239  http://www.britishmuseum.org/collectionimages/...           10
# 254240  http://www.britishmuseum.org/collectionimages/...           17
#
# [254241 rows x 4 columns]

# %%
list(df['caption.value'].sample(100))
# Out:
# [u'History of Constantine: Constantine granting their freedom back to the Roman senators; with a female personification of Rome enthroned at centre flanked by Victories, emperor Constantine standing at right accompanied by soldiers, two captives Senators at left, the she-wolf with Romulus and Remus in front of Rome; after Peter Paul Rubens.  c.1808\n\nEtching and engraving',
#  u'A young couple sitting on a sofa in the left foreground, the woman with a child on her knee which reaches towards the man, while two other children share a book on the floor in front of them; bust portrait of a man on the wall and open doorway to a bedroom in the background.\n\nMezzotint with some etching',
#  u"Scene from 'The Merry Wives of Windsor'; Falstaff, dressed as the fat woman of Brentford, beaten by a man and his two companions, running out of a building, helped by a woman, holding his hand at left; illustration to Shakespeare's 'The Merry Wives of Windsor'.  \n\nWood-engraving",
#  u'Portrait of a young lady, standing, three-quarter length, looking left; holding a squirrel (?); after Titian\n\nMezzotint',
#  u'With flock of sheep in front\nColour woodcut in the Japanese manner, in yellow, brown, blue and black',
#  u'A soldier, whole-length, raising his caliver\n\nEngraving',
#  u'Woodblock print. Anegawa Daikichi as Hayasaki dancing.',
#  u'A wooden cross beside  pond on the right and two people, one seated, on the path curving around on the left.\n\nEtching',
#  u"St Herbert's Chapel; St Herbert's Island, Derentwater; moonlit view of the lake, the gothic chapel illuminated on the wooded island in the left middle distance, boat in the right foreground, the crescent moon above; after JMW Turner (Wilton 1183); vignette to poem 'The Pleasures of Memory' in 'Poems' by Samuel Rogers (London: 1834, Cadell and Moxon, p.40); first published state.  1833\n\nEtching and engraving, printed on chine coll\xe9",
#  u'A pugilistic encounter between Mrs. Siddons (left) and her rival (right), who face each other with outstretched arms and clenched fists. Behind Mrs. Siddons (left) stands her backer, evidently her husband, holding out a lemon with an anxious expression. A fool\'s cap is held above her head by a satyr-like creature wearing a fool\'s cap who leans upon a cloud; in his left hand is a watchman\'s rattle. Behind her opponent stands her backer, probably her husband, a man wearing a hat, smiling, his hands on his hips, from a cloud above his head a man of dignified appearance with rays projecting from his head holds a laurel wreath over the head of the combatant.  Both the actresses are wearing the adaptation of contemporary dress then worn on the stage by tragedy queens; Mrs. Siddons\'s breast is bare but her rival is decorously clothed.  On the extreme left is a group of five spectators, standing below the level of the stage.   In the lower margin phrases are etched which are evidently intended to be spoken by the four principals:\n\nWilliam Siddons says, "Sweet wife! you have seen cruel proof of this woman\'s strength I beg of you for your own sake to embrace your own safety and give over this attempt".  Mrs. Siddons says, "Nay, an thou\'lt mouth, I\'ll rant as well as thou." Her opponent says, "I will fight with her upon this throne untill my eyelids will no longer wag". Her backer says, "Keep it up Nan! Devil bury me but the Goddess will soon do her over!"  c.October/November 1782\n\nEtching',
#  u'The quay at Antwerp during the fair time; view in a harbour, with number of ships mooring and smaller boats surrounding, a rowing boat in the centre foreground with several figures onboard, flanked by buoys, the left buoy among poles in the water, a church tower on the centre horizon; after Callcott.  1835\n\nEngraving and etching',
#  u"Figures gathered on the street outside the front of the church with columned fa\xe7ade and portico on the second storey; after Thomas Talbot Bury, illustration from 'Paris and its Environs'.  1829\n\nEtching and engraving",
#  u'View of a train track running through Harrow on the Hill, in north London; a steam train passing; a gruop of people seated by the side of the track, with a small fire, others watching train from raised position on the left; a church on top of hill in background to the right.\n\nSteel engraving',
#  u'A woman in classical costume carrying a basket of fruits on her head, in an oval frame flanked by two cartouches representing a naked woman and a man in armour, surmounted by torsos of satyrs; at the bottom, two putti raising their arm.  c.1540/50\nEtching',
#  u'St Margaret standing, holding a palm in her raised left hand, a dragon at her right; in the background is a tree-trunk and a large rock, after Francesco Francia\nEngraving',
#  u'Portrait of the 2nd Duke of Buckingham, three quarter length, standing, wearing cravat, chain and George, and holding a coronet; pillars and a building in the background; coat of arms in lower margin.\n\nEngraving',
#  u"Landscape with flight into Egypt; at left, St Joseph leading a donkey carrying the Virgin and Christ Child towards the right; at right, a peasant and two cows crossing a wooden bridge; a flock in the distance, at centre; unfinished proof with scratched engraver's name.  1757\n\nEtching and engraving with hand-colouring",
#  u'A tauroborium ceremony; the priests of Cybele are being baptised with the blood of a sacrificial bull, which is lying on a stage in the centre; three men including Antonius Pius are surrounding the animal; Roman temple and musicians in the background. 1774-5\n\nEtching',
#  u"Portrait of George Germaine, three-quarter length; standing at a table, directed and faced to left; looking to front; holding a sword in his left hand, his right is resting on a piece of paper inscribed 'To the King'; window in the background; coat of arms below the image; after Romney; published state.  1780\nMezzotint",
#  u'A close copy (coloured), as No. 13152 A.\n\nHand-coloured etching',
#  u'Portrait of the actor, in character; whole length, stnading, to the left, arms outstretched, struck by an arrow in the chest, holding staff with serpents and sun; after Roberts.  1799\n\nEtching with hand-colouring',
#  u'Illustration to "Fable VI. The Miser and Plutus" from Gay\'s "Fables", Vol. 1 (London, 1793); an interior with stone walls; to the left, a male figure kneeling before an open treasure chest; to the right, a nude, bearded, winged Plutus, with drape.  1793\nEngraving and etching',
#  u'Woodblock print, oban tate-e. Fujiwara no Tadabumi, insulted and struck on the head, leaves the imperial palace amid falling cherry-blossoms.',
#  u'View in crypt, with a confessional in the right foreground, prayers in the left middle distance seen from behind. \n\nEtching',
#  u"An elderly gentleman seated at centre in an armchair at a table, drinking from a small cup, another reading a paper at right, wearing spectacles, and a waiter approaching from left, carrying a coffee pot on a tray; window with curtains behind at right; proof illustration to Colman and Garrick's 'The Clandestine Marriage' in Inchbald's British Theatre'; after Henry Singleton; proof before letters.  c1816\n\nEtching and engraving on chine coll\xe9",
#  u'Man with grey beard holding a pamphlet\nMezzotint',
#  u'Night scene with woman holding a burning torch and holding out a jug to a figure lying in a bed; second state, with additional work.  c.1774/89\n\nEtching',
#  u'Portrait of Henri IV, King of France, aged 43; bust-length, facing right, wearing wide-brimed hat, ruff, and sash; in a lettered oval; copy after Goltzius. 1595\n\nEngraving',
#  u'Plate XXV: a man with a stick under one arm, and a dog curled on the ground beside him, counting money to pay for a cow held by another man who stands opposite him.  1841\n\nEtching on chine coll\xe9',
#  u'View of a lodge at the edge of a forest, with two huntsmen, carrying shotguns, walking in foreground, following two dogs; group of figures seen under a tree at far left; illustration to Sheffield Grace\'s "Memoirs of the Family of Grace" \n\nEtching and engraving',
#  u"Portrait of Ludolf Backhuysen; bust-length, turned to right; in an oval frame; accompanying Backhuysen's series of the Stroom en Zeegezichten.  c.1701\n\nMezzotint",
#  u'Satire: a country rector on a cob horse riding towards Cambridge.  2 May 1772\n\nEtching',
#  u'A cavalryman in armour raising a lance, to left\n\nEngraving',
#  u'two figures follow a sleigh pulled by dogs in the snow at right, the fort on a slight hill at left with a flag pole and the chimneys smoking; after George Back, from plate 6 from a series illustrating an arctic expedition.  1828\n\nEtching and engraving',
#  u'View of a covered bridge over a lake with houses on the side. 1782\n\nEtching with hand colouring in black and white',
#  u"A figure with a cat's head and claws, looking menacing, wearing a cloak with a fur collar; behind him, a half-blind female figure chained to a table, holding a sickle and a pair of weighing scales; beyond at left, a wheel, a structure with wooden frames, and a building with barred windows at right; illustration for 'Oeuvres de Rabelais' (Paris: Lemerre, 1872), Book V, Chapter XI; proof before letter.  c.1872\n\nEtching",
#  u'A house with a chimney and a bay window in the middle distance, trees on the left and in the background, a fence on the right, a path from the door leading to a pond in the left foreground; working proof, after the left tree and house reworked.\n\nEtching',
#  u'Two portraits, each printed on recto and verso of sheet:\n\n(Recto) Portrait of Sir Archibald Alison, half-length directed to the left, looking to the right, with short hair, in double-breasted jacket, after Raeburn; early state before buttons on jacket, printed on chine coll\xe9.  1823\n\n(Verso) Portrait of Henry Cockburn, half-length directed to the right, with bald pate, in private dress with double-breasted jacket; after Raeburn; illustration to an unidentified publication; proof.  1820\n\nStipple with engraving',
#  u'View of the Seine through two bridges which are populated by figures; Isle de la Cit\xe9 beyond; various figures and horse and carts on the embankment lower right.\nEtching',
#  u'Two small donkeys in a barn, one lying and turning its head towards a pig which lies with its back to the viewer, the other donkey standing to right, pulling straw from a manger to upper right; after Morland.  1811\n\nMezzotint',
#  u'Christ ascending in a cloud of glory, looking and gesturing up to right, with five soldiers falling in terror below, an angel sitting on the broken tomb on the right and three women approaching in the left background, one carrying a jar; dawn breaking on the horizon in the distance.\n\nHand-coloured mezzotint with etching',
#  u'Description to follow.  5 March 1749\n\nEtching and letterpress',
#  u'Plate 94: Susanna and the elders, after Cavedone; the young woman is seen standing at left, half-length, and turning towards the two elders, who are standing on the right and pleading with her; in outline.  1807/09\n\nEtching',
#  u'Broadside encouraging the discipline of table manners; family group seated at table saying grace, with letterpress and type ornaments. c.1650-1670\nWoodcut, hand-coloured with stencils',
#  u'DRAFT Trade card of Thomas White, metal tradesman',
#  u"William Tyndale being tied to the stake, with guards and a crowd on all sides; illustration to page 519 of a 16th-century edition of John Foxe, 'Acts and Monuments' ('Book of Martyrs').\n\nWoodcut",
#  u'A standing male nude holding an arrow before the trunk of a tree\nEngraving',
#  u"Hornibeck in robe and slippers, standing to right with angry expression as he shows his wife her petticoat which he found in Peregrine Pickle's chamber, who hurries towards them from left, a stag's skull mounted on the wall above them; oval frame with architectural surround, a motif of pan with pipes, drum and vine above; after Richard Corbould, illustration to 'Peregrine Pickle', from 'Cooke's Pocket Edition of Select Novels'.  1798\n\nEtching and engraving",
#  u"The Devil standing in Tottenham Court Road, next to a begging dog and a begger woman, addressing a poor man suffering from rickets, approaching at left; proof illustration to Samuel Taylor Coleridge's 'The Devil's Walk' ('He came into London by Tottenham Court Road').  1830-1831\n\nEtching",
#  u"Canal with gondolas in Venice, with Bridge of Sighs in middle ground connecting the Doge's palace, at left, with the prison; another bridge in the distance; arched composition; proof illustration to an unidentified publication.\nWood-engraving on thin paper",
#  u"Bird's eye view of the Royal Exchange, showing the south front and part of the courtyard.  1751\n\nEtching and engraving",
#  u"Plans on either side, the Peers to left with a key naming the seats, with the throne at the top and the speaker at the bottom, the Commons to right with the speaker surrounded by the benches, the Serjeant's seat at the bottom; in the centre, a procession of nobles and clerics leading Charles Brandon from the bottom towards King, enthroned at the top with knights to either side.  1749\n\nEtching and engraving",
#  u"A couple embracing in a wood in front of a rock, the man writing the woman's name on a tree on the left, with sheep nearby.  1787\n\nHand-coloured mezzotint",
#  u"Illustration to Shebbeare's 'Lydia', from 'The Novelist's Magazine'; a woman embracing a seated girl at left before a bed with tattered curtains, a shocked man at right; in decorative frame with swags, flowers and a sun with human face above.  c.1786\n\nEtching and engraving",
#  u"Interior with man shouting at a servant seated on the floor and laughing; two servants standing at right; illustration first used in 'Le Bourgeois gentilhomme', volume V, page 579 of Moli\xe8re's 'Oeuvres' (Paris: Compagnie des Libraires Associ\xe9s, 1773); 19th century impression.  c.1773\n\nEtching and engraving on chine coll\xe9",
#  u'DRAFT Trade card of Blackbeard, engraver',
#  u'Rock formation on a coast or island; a man seated in a sailing boat at right; proof illustration for a Geological publication of the Smithsonian Institution.   \n\nWood-engraving',
#  u'DRAFT Trade card of Perserverance Coach, carrier',
#  u'Head and part of the body of a peacock with a country house in the background\n\nColour woodcut',
#  u'A version of BM Satires 2538 now showing Robert Walpole as a hypocrite, half-length, in long wig and with a  grotesque sneering expression; a mask of a guileless face removed and held  in his left hand is lettered; oval frame, lettered "The Ant[i] Crarftsman Unmask\'d" and with a biblical quotation, in a rectangle. Letterpress, above "A New State Picture/Do not me Wrong, but take me Right,/P[ul]t[ne]y at lenght, will R[o]b[i]n bite." and beneath, "Ha ha ha! poor Caleb!" and two columns of verse accusing Walpole of corruption and condemning his reluctance to pursue war with France and Spain. \n\nMezzotint with engraved lettering',
#  u'Social satire on fashion: two fashionably-dressed women with broad-brimmed hats and narrow long skirts lose various false items of their attire whilst walking outdoors on a windy day; man with his new-fangled umbrella being blown aloft in the background at left; text below. 6 October 1786   \n\nHand-coloured etching',
#  u'Shepherd driving his flock under a rock bridge; trees on either side; mountains in the distance. 1830\n\nLithograph',
#  u"Picking beans, after Millet: peasant woman standing by a hedge, emptying the content of her apron into a basket; published in 'L'Art', 1875, volume I, page 162\n\nEtching",
#  u'DRAFT Trade card of Nicholas Haym, wine merchant',
#  u"Plate 12: Christ before Pilate; two soldiers are putting a cape over Christ's shoulders; Pilate stands at right and points at Christ with his sceptre.  before 1697\nEtching and engraving",
#  u"Portrait after Reynolds (Mannings 1838); half-length seated, facing forward with short wig, his left arm resting on the arm of the chair; illustration to Nichols's 'Illustrations of the literary history of the eighteenth century'.  1818\n\nStipple and etching",
#  u'Sacra Conversazione in a landscape, with the Holy Family and Sts John Baptist, Jerome and (?) Christopher.  1517\nWoodcut',
#  u'DRAFT Trade card of J. Hall, saddler and harness maker',
#  u'Coat of arms of an unidentified owner; armorial shield decorated with ermine fur and scalloped diagonal, supported by two affronted lions, and surmounted by helmet and swan\n\nEngraving, mounted on paper',
#  u'Profile portrait of Savonarola in a tondo\n\nEngraving',
#  u'Knight in armor holding a sword and a shield decorated with a griffin with a man\'s head on it; Dutch letterpress on verso; illustration to an edition of the Dutch "Biblia Sacra" (Jan van Moerentorf: 1645).  c.1645\n\nWoodcut',
#  u"Pl. 1; January: a party seated round a table drinking while skaters fall over outside; circular composition copied from Crispijn de Passe's engraving after Marten de Vos.  c.1660-4\n\nEngraving",
#  u'A poacher dog, white with dark head and spots on body, walking to left through a landscape with a pheasant in his mouth, trees behind; after Abraham Cooper, illustration from the Sporting Magazine.  1810s\n\nEtching and engraving',
#  u'Plate 48: gaunt man and his wife, with child, begging, corpses on ground to left; from an unbound album of first edition impressions, 1863.  1812-15\nEtching, burnished lavis, burin and burnisher with heavy surface tone, printed on paper with watermark "J.G.O." and shield',
#  u'Seascape, with two ships in foreground and boats behind; after Dominic Serres.  \n\nAquatint and etching, printed in brown',
#  u'A highland dance, with musicians sitting up on a ledge at right, an old man sitting in profile to left in the foreground with a man clapping enthusiastically behind him, cottages behind trees at left and mountains beyond, a dead deer lying in the shadows in the left foreground; after David Allen; proof before letters\n\nAquatint and engraving',
#  u'Nocturnal landscape with a cloudy sky and trees reflected in a river\n\nEtching and drypoint',
#  u"Vignette to David Carey's 'Life in Paris'; celebrants dancing around a pillar on which a large Cupid with butterfly wings blows bubbles.  1822\n\nWood-engraving",
#  u'Social satire; an author sits in his night-clothes and cap at a desk with inkpot and quill-pen, wearing glasses and concentrating hard; his servant stands beside him carrying a candle, with a jacket over his shoulder, yawning.  14 July 1797\n\nHand-coloured etching and aquatint',
#  u'Portrait, three-quarter length, seated to front in an armchair, with head tilted to right, looking to left; her right arm on chair arm, touching her hand with her gloved left hand; wearing a turban, pearl headdress. earrings and necklace, bracelet and rings, and jewelled brooch, ermine-trimmed gown over dark shoulderless dress with narrow lace collar; curtain above; after Ross; proof.  1841\n\nEtching and engraving',
#  u"Plate 1; satire; three labourers struggling under a mass of bundles, chairs and other objects they are taking towards a cart lettered 'Goods carefully removed in town or country / To be sold'; at left, a fourth man emerging from a doorway with two more great cases, saying, 'Here's another little parcel'.  1827 or later\nHand-coloured etching",
#  u'Portrait head three-quarter profile to right, with beard, wearing Greek cap, after a photograph by Nadar.  Late 1850s-60s?\nHeliogravure reproduction after a larger etching, reworked in etching, printed on oriental paper',
#  u'Woodblock print. Bijinga. Okita of the Naniwaya,with a cup of tea in her hands,poem above by Katsura no Mayuzumi.',
#  u'Three pigs, the nearest facing right, a sow lying behind it with the third lying behind the sow; wooden sty with the door open behind; after Morland.  1792\n\nMezzotint',
#  u'Two women greeting a gentleman, wearing dresses with large sashes and shawls, their hair dressed with a broad loop at the nape, while the man wears a cocked hat; two women further off to right, one wearing a hooded cloak.  1807\n\nEtching',
#  u'Linear abstract composition.  1948\nLithograph on backing sheet',
#  u'DRAFT Trade card of Mr Beeby, writing master',
#  u'Falstaff sitting with a glass in his right hand, his sword at his feet, his left arm around the waist of Doll Tearsheet, who sits on his knee, her arms around his neck, caressing his face, wearing a plumed hat, with Henry V and Poins laughing at them, entering in the background to right; after Fuseli (Schiff 724); etched state with scratched letters.  1795\n\nStipple and etching',
#  u'Plate 333, No 159: caricature of French vice-admiral Henri de Rigny, a balding man with curly hair and standing, turned to right, with hands in his pockets.  21 November 1833\n\nLithograph',
#  u'Portrait of Robert Cecil, half-length in an oval, wearing wig, cravat, and robe.\n\nMezzotint',
#  u'Portrait of Leopold I, King of the Belgians and Princess Charlotte of Wales; busts in profile to left, Leopold at front, Charlotte wearing pearl jewellery, Leopold wearing a uniform with a high collar, epaulettes, insignia and a sash\n\nEtching with stipple and roulette',
#  u"Portrait of Jan Uytenbogaert, 'The Goldweigher'; a well-dressed man sitting in a fur-trimmed cloak and soft beret at a table, writing in a ledger while handing a small bag to a youth who kneels beside him, with chests and barrels in right foreground, a scale hanging from a hanging-shelf above the table which is littered with bags and coins; with a picture of Moses and the brazen serpent on the wall behind and a man and woman waiting at a counter in right background; counterproof.  1639\nEtching and drypoint\n\nWatermark: Strasbourg lily (Hinterding catalogue, variant C.d.a., datable 1639)",
#  u"Portrait, half-length in a rectangular frame, directed slightly to right and looking away to left, wearing uniform with coat buttoned at the middle of his chest, epaulettes and a short wig; after Romney; state with engraver's name only.  1791\n\nEtching and engraving",
#  u'DRAFT Trade card of Allan Evans & Isaac Wane, grocer',
#  u'Print. Two girls, one with shamisen. Colour woodblock printed.',
#  u'View of a harbour seen from the sea, a boat rowing in the left foreground on choppy waves, figures on the beach in the middle distance under the light house, masts of ships behind on the left, the town in the background.\n\nWood-engraving',
#  u'A broadside with an anti-papal satire following the revival of Catholic bishoprics in England; with a wood-engraving showing in the centre a figure of John Bull, on the left being pulled by Parliamentarians, on the R by Catholics, in the left background Queen Victoria watching from a window, in the R background a figure of the Pope; with letterpress title, inscriptions, and text in two columns. (London, Purkess: [1850])',
#  u'Map of Gelderland, with battlescene, below; illustration to Kaspar Ens\' "Fama Austriaca" (Cologne: 1627)\nEngraving',
#  u'A hermit; half-length male figure, in profile to right; with shaved head and earring; wearing a skull cap and furry cloak; in oval frame; from a series of 127 woodcuts.  1582\nWoodcut',
#  u"View of Towneley Hall, seen from park, with two figures siting under large tree in the left foreground, flock and herd to the right, low wall behind, arms below; after JMW Turner (Wilton 292); illustration to 'An History of the original Parish of Whalley' by T Dunham Whitaker (vol. II, plate 5, p. 45); published state.  1800\n\nEtching and engraving"]

# %%
from dateutil.parser import parse

def is_date(string):
    try: 
        parse(string)
        return True
    except (TypeError, ValueError):
        return False

# %%
# We will extract the date + the material from the description and put into another column. 

is_date_ct = 0
got_material = 0

def stripExtras(capt):
    global is_date_ct
    global got_material
    arr = capt['caption.value'].split('\n')
    mat = 'n/a'
    orig = capt['caption.value'].strip()
    if len(arr) > 1: 
        mat = arr[-1]
        orig = '\n'.join(arr[:-1]).strip()
        got_material+=1
        
    arr = orig.split('.')
    date = 'n/a'
    if len(arr) > 1 and len(arr[-1]) > 0:
        if (is_date(arr[-1])):
            is_date_ct += 1
            date = arr[-1]
            orig = '.'.join(arr[:-1]).strip()       
        
    return pd.Series([orig, mat, date])

# def stripDates(capt):
#     #print capt
#     arr = capt['caption.value'].split('.')
#     res = 'n/a'
#     orig = capt['caption.value'].strip()
#     if len(arr) > 1:
#         print "Date: ", arr[-1]
#         print "\n\n"
#         #if (is_date(arr[-1])):
#         #    res = arr[-1]
#         #    orig = '.'.join(arr[:-1]).strip()
        
#    return pd.Series([orig, res])

df[['caption.value_cleaned', 'ext_dates', 'ext_materials']] = df.apply(stripExtras, axis=1)
df.head(10)
# Out:
#                                         caption.value  \
# 0   From the animal legend; antelope to left, anot...
# 3   Woodblock print. Giant lantern in the Kaminari...
# 6             Woodblock print. Spring night at Ginza.
# 9   Le Mont de Neuville; street winding to right b...
# 12  Monochrome woodblock print. Subodai standing. ...
# 15  Colour woodblock print with powdered mica back...
# 18         Woodblock print. Beauty with unrolled obi?
# 21  Colour woodblock print with gold leaf and powd...
# 24  Illustrated book, orihon (folding album), 5 vo...
# 27  Illustrated book, folding album, 2 vols. Varie...
#
#                                           print.value  \
# 0   http://collection.britishmuseum.org/id/object/...
# 3   http://collection.britishmuseum.org/id/object/...
# 6   http://collection.britishmuseum.org/id/object/...
# 9   http://collection.britishmuseum.org/id/object/...
# 12  http://collection.britishmuseum.org/id/object/...
# 15  http://collection.britishmuseum.org/id/object/...
# 18  http://collection.britishmuseum.org/id/object/...
# 21  http://collection.britishmuseum.org/id/object/...
# 24  http://collection.britishmuseum.org/id/object/...
# 27  http://collection.britishmuseum.org/id/object/...
#
#                                             url.value  capt_length  \
# 0   http://www.britishmuseum.org/collectionimages/...           12
# 3   http://www.britishmuseum.org/collectionimages/...           10
# 6   http://www.britishmuseum.org/collectionimages/...            6
# 9   http://www.britishmuseum.org/collectionimages/...           35
# 12  http://www.britishmuseum.org/collectionimages/...           10
# 15  http://www.britishmuseum.org/collectionimages/...           22
# 18  http://www.britishmuseum.org/collectionimages/...            6
# 21  http://www.britishmuseum.org/collectionimages/...           24
# 24  http://www.britishmuseum.org/collectionimages/...           31
# 27  http://www.britishmuseum.org/collectionimages/...           11
#
#                                 caption.value_cleaned  \
# 0   From the animal legend; antelope to left, anot...
# 3   Woodblock print. Giant lantern in the Kaminari...
# 6             Woodblock print. Spring night at Ginza.
# 9   Le Mont de Neuville; street winding to right b...
# 12  Monochrome woodblock print. Subodai standing. ...
# 15  Colour woodblock print with powdered mica back...
# 18         Woodblock print. Beauty with unrolled obi?
# 21  Colour woodblock print with gold leaf and powd...
# 24  Illustrated book, orihon (folding album), 5 vo...
# 27  Illustrated book, folding album, 2 vols. Varie...
#
#                                         ext_dates ext_materials
# 0                                         Woodcut          1912
# 3                                             n/a           n/a
# 6                                             n/a           n/a
# 9   Charcoal (?), with watercolour, over monotype          1899
# 12                                            n/a           n/a
# 15                                            n/a           n/a
# 18                                            n/a           n/a
# 21                                            n/a           n/a
# 24                                            n/a           n/a
# 27                                            n/a           n/a

# %%
print float(is_date_ct)/len(df)
print float(got_material)/len(df)

#mistake
df.rename(columns = {'ext_dates': 'materials'}, inplace = True)
df.rename(columns = {'ext_materials': 'dates'}, inplace = True)
# Out:
# 0.487049689075
# 0.921739609268

# %%
list(df.sample(10)['caption.value_cleaned'])
# Out:
# [u'Satire; two images on one plate; upper image, a group of men sitting in a political assembly; lower image, prisoners labouring with pick-axes by the coast as armed soldiers stand and look on.',
#  u'A broadside almanac for the year 1720; with an engraving by B\xe9nard showing a view of rue Quinquempoix in Paris, the street crowded with people; a shield with the sun of Louis XIV below the image. Engraved title, inscriptions, and letterpress almanac, partly printed in red, in 12 columns. (n.p.: 1720)',
#  u'At centre, Tityus chained to a rock and a bird of prey seen biting his liver; three figures seen to left; Aeneas and the Cumaean Sibyl seen in the distance, to right.',
#  u'Man elegantly dressed, on horseback, almost facing front, going slightly to the left; on white ground',
#  u'Design for a frame for the portrait of Armand Gu\xe9raud, conceived as an allegory of the history of printing, consisting of books, including one titled "CODE/LOIS" resting on a lynx, and frieze at base with Japanese characters, hieroglyphs and numbers, and two medallions',
#  u"A lobster pinching a cat's paw, preventing it from taking a large fish which lies across the table in the right foreground; inkstand, salt and knife lying nearby; after Bateman; open-letter state",
#  u'Woodblock print, oban tate-e. Sato Tadanobu, in the armour of Minamoto no Yoshitsune, overthrowing the monk Yokogawa Kakuhan in the snow by a waterfall.',
#  u'DRAFT Trade card of T Gwennap Junior, picture dealer & restorer',
#  u'Above the design: \'Michaelmas Day 1829 or the last Watchman\u2014\' Peel kicks a lean old watchman behind, and drags from his shoulders his patched and tattered coat. Just behind him (right) is a big bonfire in which a watch-box and battered lanterns are blazing; beside it lie more lanterns, a rattle, and staves. In the background a watchman hangs by the neck from the branch of a tree, still holding rattle and lantern. Beside the tree is a pond from which projects an arm clutching a rattle. Peel says: \'"But such a poor, bare-forked animal as thou art\u2014Off\u2014off you lendings: come unbutton here vide Shaks\u2014\' ["Lear", III. iv]. The terrified watchman answers: \'"Nay, take my life and all, pardon not that: You take my house, when you do take the prop That doth sustain my house; you take my life, When you do take the means whereby I live, vide Shaks.\' ["Merchant of Venice", IV. i]',
#  u"A young woman with dark hair, reclining on a sofa to right, looking towards the viewer with a sultry expression, holding a feather fan in her lap in her right hand, wearing a white gown trimmed with fur, with a dog lying at her feet and palm to left; after Clairin; engraver's proof."]

# %%
start = time.time()

#use regex to extract out parentehsis stuff
has_paren_ct = 0

import re
def stripParen(input):
    global has_paren_ct
    s = input['caption.value_cleaned']
    out = re.sub('\(.*?\)', '', s).strip()
    out = re.sub('\[.*?\]', '', out).strip()
    if s != out:
        has_paren_ct += 1
    return pd.Series([out])


df[['caption.value_cleaned2']] = df.apply(stripParen, axis=1)
print list(df.head(5)['caption.value_cleaned'])
print list(df.head(5)['caption.value_cleaned2'])
print "Time:" + str(time.time() - start)
print "Percentage affected:" + str(float(has_paren_ct)/len(df))
# Out:
# [u'From the animal legend; antelope to left, another(?) lying centre', u'Woodblock print. Giant lantern in the Kaminari-mon of Senso-ji temple.', u'Woodblock print. Spring night at Ginza.', u'Le Mont de Neuville; street winding to right beyond, flanked by buildings on both sides, at right figure in doorway and beyond figure standing in middle of road', u'Monochrome woodblock print. Subodai standing. Signed, sealed, inscribed and marked.']
# [u'From the animal legend; antelope to left, another lying centre', u'Woodblock print. Giant lantern in the Kaminari-mon of Senso-ji temple.', u'Woodblock print. Spring night at Ginza.', u'Le Mont de Neuville; street winding to right beyond, flanked by buildings on both sides, at right figure in doorway and beyond figure standing in middle of road', u'Monochrome woodblock print. Subodai standing. Signed, sealed, inscribed and marked.']
# Time:353.834106207
# Percentage affected:0.193340177233

# %%
print list(df[6000:6010]['caption.value_cleaned'])
print list(df[6000:6010]['caption.value_cleaned2'])
# Out:
# [u"Plate V: Joseph, wearing a loin-cloth and shackled, stands gesticulating before Pharaoh and his queen, enthroned with a harp player kneeling beside them at r; two guards, holding Joseph's chains, and an ibis at left", u'Business card for the mould-maker Malzieux; with decorative border around inscription, of foliage, casts and tools, figures and animals', u'Woman standing at a window, whole-length; wearing very full skirts.', u'View over rolling landscape to town, rright, with tree to left', u'Woman standing at a window, whole-length; wearing very full skirts.', u'Sheet 21 (sig. l): the page is divided into two halves, in the upper compartment God is adored by angels and kings, below the temple of God (titled) is placed above the ark of the covenant, next to wwhich two angels are swinging censers; inscriptions', u'Hunting scene; four horsemen in medieval costume in the background, with a fox chased by hound in the foreground', u'A Gothic tabernacle, shown in elevation and (on a separate plate) in groundplan', u'Kissing couple lying on a bed', u'Woman, whole-length; wearing full skirts.']
# [u"Plate V: Joseph, wearing a loin-cloth and shackled, stands gesticulating before Pharaoh and his queen, enthroned with a harp player kneeling beside them at r; two guards, holding Joseph's chains, and an ibis at left", u'Business card for the mould-maker Malzieux; with decorative border around inscription, of foliage, casts and tools, figures and animals', u'Woman standing at a window, whole-length; wearing very full skirts.', u'View over rolling landscape to town, rright, with tree to left', u'Woman standing at a window, whole-length; wearing very full skirts.', u'Sheet 21 : the page is divided into two halves, in the upper compartment God is adored by angels and kings, below the temple of God  is placed above the ark of the covenant, next to wwhich two angels are swinging censers; inscriptions', u'Hunting scene; four horsemen in medieval costume in the background, with a fox chased by hound in the foreground', u'A Gothic tabernacle, shown in elevation and  in groundplan', u'Kissing couple lying on a bed', u'Woman, whole-length; wearing full skirts.']

# %%
store = pd.HDFStore('bm_data_clean.h5')

# %%
df_to_store = df[['print.value', 'url.value', 'caption.value_cleaned2', 'materials', 'dates']]
df_to_store.head(5)
# Out:
#                                           print.value  \
# 0   http://collection.britishmuseum.org/id/object/...
# 3   http://collection.britishmuseum.org/id/object/...
# 6   http://collection.britishmuseum.org/id/object/...
# 9   http://collection.britishmuseum.org/id/object/...
# 12  http://collection.britishmuseum.org/id/object/...
#
#                                             url.value  \
# 0   http://www.britishmuseum.org/collectionimages/...
# 3   http://www.britishmuseum.org/collectionimages/...
# 6   http://www.britishmuseum.org/collectionimages/...
# 9   http://www.britishmuseum.org/collectionimages/...
# 12  http://www.britishmuseum.org/collectionimages/...
#
#                                caption.value_cleaned2  \
# 0   From the animal legend; antelope to left, anot...
# 3   Woodblock print. Giant lantern in the Kaminari...
# 6             Woodblock print. Spring night at Ginza.
# 9   Le Mont de Neuville; street winding to right b...
# 12  Monochrome woodblock print. Subodai standing. ...
#
#                                         materials  dates
# 0                                         Woodcut   1912
# 3                                             n/a    n/a
# 6                                             n/a    n/a
# 9   Charcoal (?), with watercolour, over monotype   1899
# 12                                            n/a    n/a

# %%
store['df'] = df_to_store.rename(index=str, columns={'caption.value_cleaned2': 'captions'}).reset_index(drop=True)
# Out:
# /Library/Python/2.7/site-packages/IPython/core/interactiveshell.py:2881: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->['print.value', 'url.value', 'captions', 'materials', 'dates']]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
store['df']
# Out:
#                                               print.value  \
# 0       http://collection.britishmuseum.org/id/object/...
# 1       http://collection.britishmuseum.org/id/object/...
# 2       http://collection.britishmuseum.org/id/object/...
# 3       http://collection.britishmuseum.org/id/object/...
# 4       http://collection.britishmuseum.org/id/object/...
# 5       http://collection.britishmuseum.org/id/object/...
# 6       http://collection.britishmuseum.org/id/object/...
# 7       http://collection.britishmuseum.org/id/object/...
# 8       http://collection.britishmuseum.org/id/object/...
# 9       http://collection.britishmuseum.org/id/object/...
# 10      http://collection.britishmuseum.org/id/object/...
# 11      http://collection.britishmuseum.org/id/object/...
# 12      http://collection.britishmuseum.org/id/object/...
# 13      http://collection.britishmuseum.org/id/object/...
# 14      http://collection.britishmuseum.org/id/object/...
# 15      http://collection.britishmuseum.org/id/object/...
# 16      http://collection.britishmuseum.org/id/object/...
# 17      http://collection.britishmuseum.org/id/object/...
# 18      http://collection.britishmuseum.org/id/object/...
# 19      http://collection.britishmuseum.org/id/object/...
# 20      http://collection.britishmuseum.org/id/object/...
# 21      http://collection.britishmuseum.org/id/object/...
# 22      http://collection.britishmuseum.org/id/object/...
# 23      http://collection.britishmuseum.org/id/object/...
# 24      http://collection.britishmuseum.org/id/object/...
# 25      http://collection.britishmuseum.org/id/object/...
# 26      http://collection.britishmuseum.org/id/object/...
# 27      http://collection.britishmuseum.org/id/object/...
# 28      http://collection.britishmuseum.org/id/object/...
# 29      http://collection.britishmuseum.org/id/object/...
# ...                                                   ...
# 254211  http://collection.britishmuseum.org/id/object/...
# 254212  http://collection.britishmuseum.org/id/object/...
# 254213  http://collection.britishmuseum.org/id/object/...
# 254214  http://collection.britishmuseum.org/id/object/...
# 254215  http://collection.britishmuseum.org/id/object/...
# 254216  http://collection.britishmuseum.org/id/object/...
# 254217  http://collection.britishmuseum.org/id/object/...
# 254218  http://collection.britishmuseum.org/id/object/...
# 254219  http://collection.britishmuseum.org/id/object/...
# 254220  http://collection.britishmuseum.org/id/object/...
# 254221  http://collection.britishmuseum.org/id/object/...
# 254222  http://collection.britishmuseum.org/id/object/...
# 254223  http://collection.britishmuseum.org/id/object/...
# 254224  http://collection.britishmuseum.org/id/object/...
# 254225  http://collection.britishmuseum.org/id/object/...
# 254226  http://collection.britishmuseum.org/id/object/...
# 254227  http://collection.britishmuseum.org/id/object/...
# 254228  http://collection.britishmuseum.org/id/object/...
# 254229  http://collection.britishmuseum.org/id/object/...
# 254230  http://collection.britishmuseum.org/id/object/...
# 254231  http://collection.britishmuseum.org/id/object/...
# 254232  http://collection.britishmuseum.org/id/object/...
# 254233  http://collection.britishmuseum.org/id/object/...
# 254234  http://collection.britishmuseum.org/id/object/...
# 254235  http://collection.britishmuseum.org/id/object/...
# 254236  http://collection.britishmuseum.org/id/object/...
# 254237  http://collection.britishmuseum.org/id/object/...
# 254238  http://collection.britishmuseum.org/id/object/...
# 254239  http://collection.britishmuseum.org/id/object/...
# 254240  http://collection.britishmuseum.org/id/object/...
#
#                                                 url.value  \
# 0       http://www.britishmuseum.org/collectionimages/...
# 1       http://www.britishmuseum.org/collectionimages/...
# 2       http://www.britishmuseum.org/collectionimages/...
# 3       http://www.britishmuseum.org/collectionimages/...
# 4       http://www.britishmuseum.org/collectionimages/...
# 5       http://www.britishmuseum.org/collectionimages/...
# 6       http://www.britishmuseum.org/collectionimages/...
# 7       http://www.britishmuseum.org/collectionimages/...
# 8       http://www.britishmuseum.org/collectionimages/...
# 9       http://www.britishmuseum.org/collectionimages/...
# 10      http://www.britishmuseum.org/collectionimages/...
# 11      http://www.britishmuseum.org/collectionimages/...
# 12      http://www.britishmuseum.org/collectionimages/...
# 13      http://www.britishmuseum.org/collectionimages/...
# 14      http://www.britishmuseum.org/collectionimages/...
# 15      http://www.britishmuseum.org/collectionimages/...
# 16      http://www.britishmuseum.org/collectionimages/...
# 17      http://www.britishmuseum.org/collectionimages/...
# 18      http://www.britishmuseum.org/collectionimages/...
# 19      http://www.britishmuseum.org/collectionimages/...
# 20      http://www.britishmuseum.org/collectionimages/...
# 21      http://www.britishmuseum.org/collectionimages/...
# 22      http://www.britishmuseum.org/collectionimages/...
# 23      http://www.britishmuseum.org/collectionimages/...
# 24      http://www.britishmuseum.org/collectionimages/...
# 25      http://www.britishmuseum.org/collectionimages/...
# 26      http://www.britishmuseum.org/collectionimages/...
# 27      http://www.britishmuseum.org/collectionimages/...
# 28      http://www.britishmuseum.org/collectionimages/...
# 29      http://www.britishmuseum.org/collectionimages/...
# ...                                                   ...
# 254211  http://www.britishmuseum.org/collectionimages/...
# 254212  http://www.britishmuseum.org/collectionimages/...
# 254213  http://www.britishmuseum.org/collectionimages/...
# 254214  http://www.britishmuseum.org/collectionimages/...
# 254215  http://www.britishmuseum.org/collectionimages/...
# 254216  http://www.britishmuseum.org/collectionimages/...
# 254217  http://www.britishmuseum.org/collectionimages/...
# 254218  http://www.britishmuseum.org/collectionimages/...
# 254219  http://www.britishmuseum.org/collectionimages/...
# 254220  http://www.britishmuseum.org/collectionimages/...
# 254221  http://www.britishmuseum.org/collectionimages/...
# 254222  http://www.britishmuseum.org/collectionimages/...
# 254223  http://www.britishmuseum.org/collectionimages/...
# 254224  http://www.britishmuseum.org/collectionimages/...
# 254225  http://www.britishmuseum.org/collectionimages/...
# 254226  http://www.britishmuseum.org/collectionimages/...
# 254227  http://www.britishmuseum.org/collectionimages/...
# 254228  http://www.britishmuseum.org/collectionimages/...
# 254229  http://www.britishmuseum.org/collectionimages/...
# 254230  http://www.britishmuseum.org/collectionimages/...
# 254231  http://www.britishmuseum.org/collectionimages/...
# 254232  http://www.britishmuseum.org/collectionimages/...
# 254233  http://www.britishmuseum.org/collectionimages/...
# 254234  http://www.britishmuseum.org/collectionimages/...
# 254235  http://www.britishmuseum.org/collectionimages/...
# 254236  http://www.britishmuseum.org/collectionimages/...
# 254237  http://www.britishmuseum.org/collectionimages/...
# 254238  http://www.britishmuseum.org/collectionimages/...
# 254239  http://www.britishmuseum.org/collectionimages/...
# 254240  http://www.britishmuseum.org/collectionimages/...
#
#                                                  captions  \
# 0       From the animal legend; antelope to left, anot...
# 1       Woodblock print. Giant lantern in the Kaminari...
# 2                 Woodblock print. Spring night at Ginza.
# 3       Le Mont de Neuville; street winding to right b...
# 4       Monochrome woodblock print. Subodai standing. ...
# 5       Colour woodblock print with powdered mica back...
# 6              Woodblock print. Beauty with unrolled obi?
# 7       Colour woodblock print with gold leaf and powd...
# 8       Illustrated book, orihon , 5 vols . Instructio...
# 9       Illustrated book, folding album, 2 vols. Varie...
# 10      Woodblock print. Woman reading with cat. Colours.
# 11      Woodblock print from an album of 37 sheets. Br...
# 12      Woodblock print from an album of 37 sheets. Gr...
# 13      Woodblock print from an album of 37 sheets. Eb...
# 14      Woodblock print from an album of thirty-seven ...
# 15      Woodblock print from an album of 37 sheets. Pe...
# 16      Woodblock print from an album of 37 sheets. Th...
# 17      Woodblock print from an album of thirty-seven ...
# 18      Woodblock print from an album of 37 sheets. Cr...
# 19      Woodblock print from an album of 37 sheets. Du...
# 20      Woodblock print from an album of 37 sheets. La...
# 21      Woodblock print from an album of 37 sheets. Pe...
# 22      Woodblock print from an album of 37 sheets. Mo...
# 23      Woodblock print from an album of 37 sheets. Lo...
# 24      Woodblock print from an album of 37 sheets. Le...
# 25      Woodblock print from an album of 37 sheets. Pe...
# 26      Woodblock print from an album of 37 sheets. Ev...
# 27      Woodblock print from an album of 37 sheets. Gi...
# 28      Woodblock print from an album of 37 sheets. Th...
# 29      Woodblock print from an album of 37 sheets. Th...
# ...                                                   ...
# 254211  Woodblock print. Bijinga. Woman stretching a l...
# 254212  Colour woodblock print, oban. A mother reading...
# 254213  Woodblock print. Bijinga. Girl holding a fan b...
# 254214  Woodblock print. Bijinga. Woman sitting with d...
# 254215  Woodblock print. Bijinga. Hanamurasaki of the ...
# 254216  Woodblock print.History, myth and legend. Warr...
# 254217  Woodblock print. Uki-e. Combining scenes from ...
# 254218  Woodblock print. Deer and pine tree, advertise...
# 254219  Hand-coloured woodblock print, mounted as hang...
# 254220  Woodblock print, hand coloured, mounted as a h...
# 254221  Woodblock print mounted as a hanging scroll. T...
# 254222  Woodblock print. Kabuki. Actor Iwai Hanshiro a...
# 254223  Colour woodblock pillar print, hashira-e. Shid...
# 254224  Woodblock print.Nagasaki-e. Seascape. A Dutch ...
# 254225  Colour woodblock print, Oban. Portrait of the ...
# 254226  Woodblock print. Bijinga. Yosoi of the Matsuba...
# 254227  Colour woodblock print with powdered mica grou...
# 254228  Woodblock print.Classical literature. Love tha...
# 254229  Woodblock print. Bijinga. Hanazuma of the Hyog...
# 254230  Colour woodblock print. The kabuki actor Otani...
# 254231  Woodblock print. Kabuki. Actor Matsumoto Koshi...
# 254232  Woodblock print.Townscape. Masaki after a heav...
# 254233  Woodblock print. Carp leaping up a waterfall. ...
# 254234  Colour woodblock print, one sheet of an oban t...
# 254235  Woodblock print. Bijinga. Courtesan parading i...
# 254236  Woodblock print. Popular culture. Girl behind ...
# 254237  Woodblock print. Facsimile reproduction. The k...
# 254238  Woodblock print. Itinerant noodle vendor. Acco...
# 254239  Woodblock print. Popular culture. Lady attendi...
# 254240  Woodblock print. Straw dragon on a bamboo pole...
#
#                                             materials  dates
# 0                                             Woodcut   1912
# 1                                                 n/a    n/a
# 2                                                 n/a    n/a
# 3       Charcoal (?), with watercolour, over monotype   1899
# 4                                                 n/a    n/a
# 5                                                 n/a    n/a
# 6                                                 n/a    n/a
# 7                                                 n/a    n/a
# 8                                                 n/a    n/a
# 9                                                 n/a    n/a
# 10                                                n/a    n/a
# 11                                                n/a    n/a
# 12                                                n/a    n/a
# 13                                                n/a    n/a
# 14                                                n/a    n/a
# 15                                                n/a    n/a
# 16                                                n/a    n/a
# 17                                                n/a    n/a
# 18                                                n/a    n/a
# 19                                                n/a    n/a
# 20                                                n/a    n/a
# 21                                                n/a    n/a
# 22                                                n/a    n/a
# 23                                                n/a    n/a
# 24                                                n/a    n/a
# 25                                                n/a    n/a
# 26                                                n/a    n/a
# 27                                                n/a    n/a
# 28                                                n/a    n/a
# 29                                                n/a    n/a
# ...                                               ...    ...
# 254211                                            n/a    n/a
# 254212                                            n/a    n/a
# 254213                                            n/a    n/a
# 254214                                            n/a    n/a
# 254215                                            n/a    n/a
# 254216                                            n/a    n/a
# 254217                                            n/a    n/a
# 254218                                            n/a    n/a
# 254219                                            n/a    n/a
# 254220                                            n/a    n/a
# 254221                                            n/a    n/a
# 254222                                            n/a    n/a
# 254223                                            n/a    n/a
# 254224                                            n/a    n/a
# 254225                                            n/a    n/a
# 254226                                            n/a    n/a
# 254227                                            n/a    n/a
# 254228                                            n/a    n/a
# 254229                                            n/a    n/a
# 254230                                            n/a    n/a
# 254231                                            n/a    n/a
# 254232                                            n/a    n/a
# 254233                                            n/a    n/a
# 254234                                            n/a    n/a
# 254235                                            n/a    n/a
# 254236                                            n/a    n/a
# 254237                                            n/a    n/a
# 254238                                            n/a    n/a
# 254239                                            n/a    n/a
# 254240                                            n/a    n/a
#
# [254241 rows x 5 columns]

# %%
import pandas as pd
df = pd.read_hdf('bm_data_clean.h5', 'table')
# Out:
# ---------------------------------------------------------------------------
# HDF5ExtError                              Traceback (most recent call last)
# <ipython-input-3-0372d625f527> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_hdf('bm_data_clean.h5', 'table')
#
# /Library/Python/2.7/site-packages/pandas/io/pytables.pyc in read_hdf(path_or_buf, key, **kwargs)
#     305         # can't auto open/close if we are using an iterator
#     306         # so delegate to the iterator
# --> 307         store = HDFStore(path_or_buf, **kwargs)
#     308         auto_close = True
#     309
#
# /Library/Python/2.7/site-packages/pandas/io/pytables.pyc in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     398         self._fletcher32 = fletcher32
#     399         self._filters = None
# --> 400         self.open(mode=mode, **kwargs)
#     401
#     402     @property
#
# /Library/Python/2.7/site-packages/pandas/io/pytables.pyc in open(self, mode, **kwargs)
#     534
#     535         try:
# --> 536             self._handle = tables.open_file(self._path, self._mode, **kwargs)
#     537         except (IOError) as e:  # pragma: no cover
#     538             if 'can not be written' in str(e):
#
# /Library/Python/2.7/site-packages/tables/file.pyc in open_file(filename, mode, title, root_uep, filters, **kwargs)
#     316
#     317     # Finally, create the File instance, and return it
# --> 318     return File(filename, mode, title, root_uep, filters, **kwargs)
#     319
#     320 openFile = previous_api(open_file)
#
# /Library/Python/2.7/site-packages/tables/file.pyc in __init__(self, filename, mode, title, root_uep, filters, **kwargs)
#     782
#     783         # Now, it is time to initialize the File extension
# --> 784         self._g_new(filename, mode, **params)
#     785
#     786         # Check filters and set PyTables format version for new files.
#
# tables/hdf5extension.pyx in tables.hdf5extension.File._g_new (tables/hdf5extension.c:5458)()
#
# HDF5ExtError: HDF5 error back trace
#
#   File "H5F.c", line 604, in H5Fopen
#     unable to open file
#   File "H5Fint.c", line 1087, in H5F_open
#     unable to read superblock
#   File "H5Fsuper.c", line 277, in H5F_super_read
#     file signature not found
#
# End of HDF5 error back trace
#
# Unable to open/create file 'bm_data_clean.h5'
