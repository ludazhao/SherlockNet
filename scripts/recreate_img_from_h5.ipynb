# %% [markdown]
# This notebook is used to recreate a few folder with all images of a few tags to run the eval.lua captioning script in.

# %%
import h5py
import os
import cPickle as pickle
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import collections
import scipy.misc


# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tags = ['nature', 'landscapes']
labels = ['animals', 'nature', 'text', 'maps', 'people', 'seals', 'miniatures', 'objects', 'architecture', 'decorations', 'landscapes', 'diagrams']

# %%
image_hdf5 = h5py.File('/data/image_data.hdf5','r')

# %%
scores = h5py.File('/data/all_scores_12class.hdf5', 'r')

# %%
d = pickle.load(open("/data/all_metadata_1M_tags.pkl", 'r'))

# %%
(image_metadata, book_metadata, image_to_idx) = d

# %%
count = 0

DATA_DIR = '/data/images_raw_1M/'
for ind, (fn, _, _, tag) in image_metadata.items():
    i = ind / 5000
    idx = ind % 5000
    if tag in tags:
        img = image_hdf5["Chunk{}".format(i)][idx]
        scipy.misc.imsave(DATA_DIR+tag+'/'+fn+'.jpg', img[:,:,0])
    if (count % 1000 == 0):
        print count
    count +=1
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# ...

# %%
res = []
for ind, (fn, _, _, tag) in image_metadata.items():
    if tag == 'people':
        res.append(ind)
        
len(res)
# Out:
# 190564

# %%
ind = random.choice(res[:1000])
print image_metadata[ind][-1]
i = ind / 5000
idx = ind % 5000
print ind
print i, idx
plt.imshow(image_hdf5["Chunk{}".format(i)][idx][:,:,0], cmap=mpl.cm.gray)
print scores["Chunk{}".format(i)][idx]
# Out:
# people
# 13326
# 2 3326
# [  2.18376338e-01   8.33272934e-02   8.48860582e-05   2.39312183e-03
#    5.01265526e-01   9.22355503e-02   2.59569442e-05   9.90544930e-02
#    7.33088993e-04   1.42805290e-03   1.06972281e-03   5.98093584e-06]

# %%
import time
t= time.time()
idx = 0
for idx in range(194):
    #img = image_hdf5["Chunk{}".format(i)][idx][:,:,0]
    scipy.misc.imsave('test.jpg', image_hdf5["Chunk{}".format(i)][idx][:,:,0])
print time.time() - t
# Out:
# 0.270385026932
